# %%
#import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pyspark.sql import Row
from pyspark.sql.functions import col, udf, lag, rank, lit
from pyspark.sql.window import Window
import talib

# %%
global DoEval #是否進行模型評估

next_date_range_12 = ["20180619", "20180620", "20180621", "20180622"] #設定預測區間
next_date_range_11 = ["20180611", "20180612", "20180613", "20180614", "20180615"] #設定預測區間
next_date_range_10 = ["20180604", "20180605", "20180606", "20180607", "20180608"] #設定預測區間
next_date_range_9 = ["20180528", "20180529", "20180530", "20180531", "20180601"] #設定預測區間
next_date_range_8 = ["20180521", "20180522", "20180523", "20180524", "20180525"] #設定預測區間
next_date_range_7 = ["20180514", "20180515", "20180516", "20180517", "20180518"] #設定預測區間
ignore_dates = [""]#設定排除日(如端午節)
next_date_range_6 = ["20180507", "20180508", "20180509", "20180510", "20180511"] #設定預測區間

train_date_range = [next_date_range_6, next_date_range_7, next_date_range_8, next_date_range_9, next_date_range_10, next_date_range_11]
pred_date_range = next_date_range_12

predict_start_date = pred_date_range[0]

if sc.master[0:5]=="local":
#     Path = "file:/c:/D Drive/work/bigData/pySpark/TBrain_Round2_DataSet_20180601"
    #Path = "file:/Users/yungchuanlee/Documents/learn/AI競賽/ETF預測/TBrain_Round2_DataSet_20180511"
    Path = "file:/home/hduser/app/bigdata/competition/etf/TBrain_Round2_DataSet_20180615"
else:
    Path = "hdfs://master:9000/user/hduser"
Path = "file:/home/hduser/app/bigdata/competition/etf/TBrain_Round2_DataSet_20180615"

# %%
#define alias of columns
col_alias_etf= {"代碼":"etf_id", "日期": "etf_date", "中文簡稱": "etf_name", "開盤價(元)":"etf_open", 
            "最高價(元)":"etf_high", "最低價(元)":"etf_low", "收盤價(元)":"etf_close", "成交張數(張)":"etf_count"}
col_alias_stock= {"代碼":"stock_id", "日期": "stock_date", "中文簡稱": "stock_name", "開盤價(元)":"stock_open", 
            "最高價(元)":"stock_high", "最低價(元)":"stock_low", "收盤價(元)":"stock_close", "成交張數(張)":"stock_count"}#udf
def to_double(str_val):
    return float(str_val.replace(",",""))
to_double=udf(to_double)

# %%
#def function to read data (因檔案格式都相同)
def read_data(file_name, col_alias):
    str_cols = ["代碼","日期", "中文簡稱"]
    raw_data = spark.read.option("encoding", "Big5").csv(Path + "/" + file_name, header=True, sep=",")
    print("Total " + file_name + " count: " + str(raw_data.count()))
    #rename cols and correct type 
    num_cols = [col_name for col_name in raw_data.columns if col_name not in str_cols]
    final_data=raw_data.select( [col(str_col_name).alias(col_alias[str_col_name]) for str_col_name in str_cols] + 
                                  [to_double(col(num_col_name)).cast("double").alias(col_alias[num_col_name]) for num_col_name in num_cols] )
    final_data.printSchema()
    final_data.show(5)
    return final_data

# %%
print("starting import tetfp.csv(台灣18檔ETF股價資料)...")
tetfp_dt=read_data("tetfp.csv", col_alias_etf)
# Out:
# starting import tetfp.csv(台灣18檔ETF股價資料)...
# Total tetfp.csv count: 19665
# root
#  |-- etf_id: string (nullable = true)
#  |-- etf_date: string (nullable = true)
#  |-- etf_name: string (nullable = true)
#  |-- etf_open: double (nullable = true)
#  |-- etf_high: double (nullable = true)
#  |-- etf_low: double (nullable = true)
#  |-- etf_close: double (nullable = true)
#  |-- etf_count: double (nullable = true)
#
# +-------+--------+----------------+--------+--------+-------+---------+---------+
# | etf_id|etf_date|        etf_name|etf_open|etf_high|etf_low|etf_close|etf_count|
# +-------+--------+----------------+--------+--------+-------+---------+---------+
# |0050   |20130102|元大台灣50          |    54.0|   54.65|   53.9|     54.4|  16487.0|
# |0050   |20130103|元大台灣50          |    54.9|   55.05|  54.65|    54.85|  29020.0|
# |0050   |20130104|元大台灣50          |   54.85|   54.85|   54.4|     54.5|   9837.0|
# |0050   |20130107|元大台灣50          |   54.55|   54.55|   53.9|    54.25|   8910.0|
# |0050   |20130108|元大台灣50          |    54.0|    54.2|  53.65|     53.9|  12507.0|
# +-------+--------+----------------+--------+--------+-------+---------+---------+
# only showing top 5 rows

# %%
#取出etf的distinct id
etf_ids = []
etf_idx_dic = {}
etf_idx = 0
for row in tetfp_dt.select("etf_id").distinct().orderBy("etf_id").collect():
    etf_ids.append(row["etf_id"])
    etf_idx_dic.update({row["etf_id"]: etf_idx})
    etf_idx += 1
etf_idx_dic
# etf_ids = ['0050   ']
# Out:
# {'0050   ': 0,
#  '0051   ': 1,
#  '0052   ': 2,
#  '0053   ': 3,
#  '0054   ': 4,
#  '0055   ': 5,
#  '0056   ': 6,
#  '0057   ': 7,
#  '0058   ': 8,
#  '0059   ': 9,
#  '006201 ': 10,
#  '006203 ': 11,
#  '006204 ': 12,
#  '006208 ': 13,
#  '00690  ': 14,
#  '00692  ': 15,
#  '00701  ': 16,
#  '00713  ': 17}

# %%
etf_dic = {}
for etfid in etf_ids:
    export_dt = tetfp_dt.filter("etf_id='" +etfid+ "' and etf_date < '" + predict_start_date + "'") \
        .orderBy("etf_id", "etf_date", ascending=True)
    export_pd = export_dt.toPandas()
    etf_dic.update({etfid.strip(): export_pd})

# %%
#functions of TA lib
#print(talib.get_functions())
print(tetfp_dt.filter("etf_date < '20180611'").count())
# Out:
# 19575

# %%
# etf_dic["0050"]["etf_close"].count()

# %%
import math
def avg_list(p_list):
    #計算數字list的平均值
    return sum(p_list)/len(p_list)

def get_feature_pre(curr_list):
    #在feature前加上一個Nan後回傳, 第二個值則回傳原本的最後一個值作為下次的feature
    if type(curr_list) is pd.Series:
        rtn_list = curr_list.tolist()
    else:
        rtn_list = curr_list
    rtn_list = [None] + rtn_list
    return (rtn_list[:-1], [rtn_list[-1]])

def checkNan(num):
    if num == None:
        return True
    elif math.isnan(num):
        return True
    else:
        return False
    
def calculate_n_bias(close_price, ma):
#     (close price - MA)/MA
    if checkNan(close_price) or checkNan(ma):
        return None
    else:
        return (close_price - ma)/ma
    
def calculate_n_bias_list(close_ser, ma_list):
    #calculate n bias (20 days)
    bias_list = []
    for cprice, ma in zip(close_ser.tolist(), ma_list):
        bias_list.append(calculate_n_bias(cprice, ma))
    return bias_list

def calculate_bias_ma_list(ma3_list, ma6_list):
    #calculate bias_ma = (ma3-ma6)/ma6
    bias_list = []
    for ma3, ma6 in zip(ma3_list, ma6_list):
        bias_list.append(calculate_n_bias(ma3, ma6))
    return bias_list

def calculate_bias_3_6_list(bias3_list, bias6_list):
    #bias_3_6 = bias3 - bias6
    bias_list = []
    for bias3, bias6 in zip(bias3_list, bias6_list):
        if checkNan(bias3) or checkNan(bias6):
            bias_list.append(None)
        else:
            bias_list.append(bias3 - bias6)
    return bias_list

def calculate_dif(ema12_list, ema26_list):
    #差離值DIF = 12日EMA - 26日EMA 
    dif_list = []
    for ema12, ema26 in zip(ema12_list, ema26_list):
        if checkNan(ema12) or checkNan(ema26):
            dif_list.append(None)
        else:
            dif_list.append(ema12 - ema26)
    return dif_list
def calculate_slope(cur_list, prev_list):
    slope_list = []
    for cur, prev in zip(cur_list, prev_list):
        if checkNan(cur) or checkNan(prev):
            slope_list.append(None)
        else:
            slope_list.append((cur-prev)/prev)
    return slope_list

from sklearn.preprocessing import StandardScaler, MinMaxScaler
import itertools
def create_feature(etf_pd, next_date, scaler_dic):
    close_ser = etf_pd["etf_close"]
    #EMA
    ema3 = talib.EMA(close_ser,timeperiod=3)
    ema3_prev, _ = get_feature_pre(ema3)
    ema3_slope = calculate_slope(ema3, ema3_prev)
    ema5 = talib.EMA(close_ser,timeperiod=5)
    ema5_prev, _ = get_feature_pre(ema5)
    ema5_slope = calculate_slope(ema5, ema5_prev)
    ema10 = talib.EMA(close_ser,timeperiod=10)
    ema10_prev, _ = get_feature_pre(ema10)
    ema10_slope = calculate_slope(ema10, ema10_prev)
    ema20 = talib.EMA(close_ser,timeperiod=20)
    ema30 = talib.EMA(close_ser,timeperiod=30)
    
    #make diff
    close_ser_prev, _ = get_feature_pre(close_ser)
    close_diff = calculate_dif(close_ser.tolist(), close_ser_prev)
    
    close_diff_2, _ = get_feature_pre(close_diff)
    close_diff_3, _ = get_feature_pre(close_diff_2)
    #BIAS
    #nBIAS -3, 6, 20 => (close price - MA)/MA   ,Paper 建議用20日MA
    ma3 = talib.MA(np.array(close_ser), timeperiod=3)
    ma6 = talib.MA(np.array(close_ser), timeperiod=6)
    ma20 = talib.MA(np.array(close_ser), timeperiod=20)
    nbias3 = calculate_n_bias_list(close_ser, ma3)
    nbias6 = calculate_n_bias_list(close_ser, ma6)
    nbias20 = calculate_n_bias_list(close_ser, ma20)
    
    #BIAS_ma = (ma3-ma6)/ma6
    bias_ma = calculate_bias_ma_list(ma3, ma6)
    
    #bias_3_6 = bias3 - bias6
    bias_3_6 = calculate_bias_3_6_list(nbias3, nbias6)
    
    #KD --> only use STOCHRSI
    k, d = talib.STOCHRSI(close_ser, timeperiod=9, fastk_period=3, fastd_period=3, fastd_matype=0)
    
    #差離值DIF = 12日EMA - 26日EMA 
    ema12 = talib.EMA(close_ser,timeperiod=12)
    ema26 = talib.EMA(close_ser,timeperiod=26)
    dif = calculate_dif(ema12, ema26)
    
    #MACD
#     macd1, macdsignal1, macdhist1 = talib.MACD(close_ser, fastperiod=12, slowperiod=26, signalperiod=9)
    macd1, macdsignal1, macdhist1 = talib.MACDEXT(close_ser, fastperiod=12, fastmatype=0, 
                                               slowperiod=26, slowmatype=0, signalperiod=9, signalmatype=0)
#     macd1, macdsignal1, macdhist1 = talib.MACDFIX(close_ser, signalperiod=9)
    #RSI
    rsi = talib.RSI(close_ser, timeperiod=10)
    
    #CMO
    cmo = talib.CMO(close_ser, timeperiod=14)
    
    #ROCR - Rate of change ratio: (price/prevPrice)
    #rocr = talib.ROCR(close_ser, timeperiod=10)
    #ROC - Rate of change : ((price/prevPrice)-1)*100
    rocr = talib.ROC(close_ser, timeperiod=10)
    
    #PPO - Percentage Price Oscillator
    ppo = talib.PPO(close_ser, fastperiod=12, slowperiod=26, matype=0)
    #APO - Absolute Price Oscillator
    apo = talib.APO(close_ser, fastperiod=12, slowperiod=26, matype=0)
    
    #MOM - Momentum
    mom = talib.MOM(close_ser, timeperiod=10)
    #TRIX - 1-day Rate-Of-Change (ROC) of a Triple Smooth EMA
    trix = talib.TRIX(close_ser, timeperiod=30)
    #作標準化
    etfid = etf_pd["etf_id"].tolist()[0]
    tmp_pd = pd.DataFrame({"etf_id": etfid, "etf_date": etf_pd["etf_date"], "etf_close": close_ser, "close_dif": close_diff,  
#                            "close_diff_1": close_diff, "close_diff_2": close_diff_2, "close_diff_3": close_diff_3,
                           "ema3":ema3, "ema5": ema5, "ema10": ema10, "ema20": ema20, "ema30" : ema30,
                           "ema3_slope": ema3_slope, "ema5_slope": ema5_slope, "ema10_slope": ema10_slope,
                          "nbias3": nbias3, "nbias6": nbias6, "nbias20": nbias20, "bias_ma": bias_ma,
                          "bias_3_6": bias_3_6, "k": k, "d": d, "dif": dif,
                          #"macd": macd, "macdsignal": macdsignal, "macdhist": macdhist,
                          "macd1": macd1, "macdsignal1": macdsignal1, "macdhist1": macdhist1,
                          "rsi": rsi, "cmo": cmo, "rocr": rocr, "ppo": ppo}).dropna(how='any')
    tmp_pd = tmp_pd[tmp_pd['etf_date'] > '20140101']
    #exclude outlier
#     for col in [c for c in tmp_pd.columns.values if c not in ["etf_id", "etf_date"]]:
#         tmp_pd = tmp_pd[np.abs(tmp_pd[col] - tmp_pd[col].mean()) <= 3.0*tmp_pd[col].std()] #只取3倍以內標準差資料
    
    std_dic = {}
    for col in [c for c in tmp_pd.columns.values if c not in ["etf_id", "etf_date"]]:
#         scaler_key = etfid.strip() + '-' + col
        scaler_key = col
        if scaler_key in scaler_dic:
            scaler = scaler_dic[scaler_key]
            merged = list(itertools.chain.from_iterable(scaler.transform(tmp_pd[[col]])))                
#             merged = tmp_pd[col]
        else:
            scaler = MinMaxScaler()
            merged = list(itertools.chain.from_iterable(scaler.fit_transform(tmp_pd[[col]])))
            merged = tmp_pd[col]
            #保留etf_close的scaler在後續使用
            scaler_dic.update({scaler_key: scaler})
        std_dic.update({col: merged})
    
    #作出目前的feature table及預測用的feature table
    ema3, next_ema3 = get_feature_pre(std_dic["ema3"])
    ema3_slope, next_ema3_slope = get_feature_pre(std_dic["ema3_slope"])
    ema5, next_ema5 = get_feature_pre(std_dic["ema5"])
    ema5_slope, next_ema5_slope = get_feature_pre(std_dic["ema5_slope"])
    ema10, next_ema10 = get_feature_pre(std_dic["ema10"])
    ema10_slope, next_ema10_slope = get_feature_pre(std_dic["ema10_slope"])
    ema20, next_ema20 = get_feature_pre(std_dic["ema20"])
    ema30, next_ema30 = get_feature_pre(std_dic["ema30"])
    
    nbias3, next_nbias3 = get_feature_pre(std_dic["nbias3"])
    nbias6, next_nbias6 = get_feature_pre(std_dic["nbias6"])
    nbias20, next_nbias20 = get_feature_pre(std_dic["nbias20"])
    
    bias_ma, next_bias_ma = get_feature_pre(std_dic["bias_ma"])
    bias_3_6, next_bias_3_6 = get_feature_pre(std_dic["bias_3_6"])
    k, next_k = get_feature_pre(std_dic['k'])
    d, next_d = get_feature_pre(std_dic['d'])
    dif, next_dif = get_feature_pre(std_dic['dif'])
    
    #macd, next_macd = get_feature_pre(std_dic['macd'])
    #macdsignal, next_macdsignal = get_feature_pre(std_dic['macdsignal'])
    #macdhist, next_macdhist = get_feature_pre(std_dic['macdhist'])
    macd1, next_macd1 = get_feature_pre(std_dic['macd1'])
    macdsignal1, next_macdsignal1 = get_feature_pre(std_dic['macdsignal1'])
    macdhist1, next_macdhist1 = get_feature_pre(std_dic['macdhist1'])
                                               
    rsi, next_rsi = get_feature_pre(std_dic['rsi'])
    cmo, next_cmo = get_feature_pre(std_dic['cmo'])
    rocr, next_rocr = get_feature_pre(std_dic['rocr'])
    ppo, next_ppo = get_feature_pre(std_dic['ppo'])
    
#     close_diff_1, next_close_diff_1 = get_feature_pre(std_dic['close_diff_1'])
#     close_diff_2, next_close_diff_2 = get_feature_pre(std_dic['close_diff_2'])
#     close_diff_3, next_close_diff_3 = get_feature_pre(std_dic['close_diff_3'])
    
    #"apo": apo, "mom": mom, "trix": trix
#     apo, next_apo = get_feature_pre(std_dic['apo'])
#     mom, next_mom = get_feature_pre(std_dic['mom'])
#     trix, next_trix = get_feature_pre(std_dic['trix'])
#     print(len(std_dic['etf_close']), ' ', len(close_diff_1), ' ', len(close_diff_2), ' ' , len(rsi))
    
    rtn_pd = pd.DataFrame({"etf_id": etfid, "idx": etf_idx_dic[etfid], "etf_date": tmp_pd["etf_date"], 
                           "etf_close": std_dic["etf_close"], "close_dif": std_dic['close_dif'], 
                           'ema3': ema3, "ema5": ema5, "ema10": ema10, "ema20": ema20, "ema30" : ema30,
                          "ema3_slope": ema3_slope, "ema5_slope": ema5_slope, "ema10_slope": ema10_slope,
                           "nbias3": nbias3, "nbias6": nbias6, "nbias20": nbias20, "bias_ma": bias_ma,
                          "bias_3_6": bias_3_6, "k": k, "d": d, "dif": dif,
                          #"macd": macd, "macdsignal": macdsignal, "macdhist": macdhist,
                           "macd1": macd1, "macdsignal1": macdsignal1, "macdhist1": macdhist1,
                          "rsi": rsi, "cmo": cmo, "rocr": rocr, "ppo": ppo}).dropna(how='any')
    #col = 'close_dif'
    #rtn_pd = rtn_pd[np.abs(rtn_pd[col] - rtn_pd[col].mean()) <= 3.0*rtn_pd[col].std()] #只取3倍以內標準差資料
    
    next_pd = pd.DataFrame({"etf_id": etfid, "idx": etf_idx_dic[etfid], "etf_date": next_date, 
                            'etf_close': -1.0, "close_dif": -1.0, 
                           "ema3": next_ema3, "ema5": next_ema5, "ema10": next_ema10, "ema20": next_ema20, "ema30" : next_ema30,
                          "ema3_slope": next_ema3_slope, "ema5_slope": next_ema5_slope, "ema10_slope": next_ema10_slope,
                            "nbias3": next_nbias3, "nbias6": next_nbias6, "nbias20": next_nbias20, "bias_ma": next_bias_ma,
                          "bias_3_6": next_bias_3_6, "k": next_k, "d": next_d, "dif": next_dif,
                          #"macd": next_macd, "macdsignal": next_macdsignal, "macdhist": next_macdhist,
                            "macd1": next_macd1, "macdsignal1": next_macdsignal1, "macdhist1": next_macdhist1,
                          "rsi": next_rsi, "cmo": next_cmo, "rocr": next_rocr, "ppo": next_ppo})
    
    return (rtn_pd, next_pd, scaler_dic)

# %%
# val = etf_dic["0050"][["etf_close"]]
# # print(val["etf_close"].tolist())
# from sklearn.preprocessing import StandardScaler
# import itertools
# scaler = StandardScaler()
# scaler.fit_transform(val)
# #merged = list(itertools.chain.from_iterable(scaler.fit_transform(val)))
# #merged
# scaler.inverse_transform([-1.44880072])[0]

# %%
#create feature pandas
etf_pd_dic = {}
next_pd_dic = {}
scaler_dic = {}
for etfid in etf_ids:
    etf_pd, next_pd, scalers = create_feature(etf_dic[etfid.strip()], predict_start_date, {})
    etf_pd_dic.update({etfid.strip() : etf_pd})
    next_pd_dic.update({etfid.strip() : next_pd})
    scaler_dic.update(scalers)

# %%
# etf_pd_dic["0050"]['etf_close'].describe()

# %%
#etf_pd_dic["0054"].describe()

# %%
#etf_pd_dic["00692"].describe()

# %%
from sklearn.preprocessing import MinMaxScaler
import itertools
# pd_0050=etf_pd_dic["0051"]
# pd_0050=pd_0050[pd_0050.etf_date > '20180101']
# scaler = MinMaxScaler()
# pd_0050['close_dif']=list(itertools.chain.from_iterable(scaler.fit_transform(pd_0050[['close_dif']])))
# # pd_0050[['close_dif']].plot()
# for col in list(pd_0050.columns.values): #["bias_3_6", "ema5_slope", 'ema10_slope']:
#     pd_0050[col]=list(itertools.chain.from_iterable(scaler.fit_transform(pd_0050[[col]])))
#     pd_0050[['close_dif',col]].plot()
# plt.show()

# %%
#non_feature_list = ['etf_id', 'etf_date', 'close_dif', 'etf_close', 'idx']
#feature_cols = [col for col in list(etf_pd_dic["0050"].columns.values) if col not in non_feature_list]
# feature_cols = ['ema5']
#print(feature_cols)

# %%
list('bias_3_6,ema20,ema30,macd1'.split(','))
# Out:
# ['bias_3_6', 'ema20', 'ema30', 'macd1']

# %%
import xgboost as xgb
def trainModel(train_dt, feature_cols, f_type):
    train_x1 = train_dt[feature_cols].values
    if f_type == '1':
        #model for close_dif
        train_y1 = train_dt["close_dif"].values
        #$$$ parameter
        model1 = xgb.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75, 
            colsample_bytree=1, max_depth=68, n_jobs=4, min_child_weight=0 )
        model1.fit(train_x1, train_y1)
        return model1
    else:
        #model for etf_close
        train_y2 = train_dt["etf_close"].values
        model2 = xgb.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75, 
            colsample_bytree=1, max_depth=68, n_jobs=4, min_child_weight=0 )
        model2.fit(train_x1, train_y2)
        return model2

# %%
eval_date_range = []
for date_range in train_date_range:
    eval_date_range += date_range
eval_date_range += pred_date_range

pd_0050=etf_dic["0050"]
prev_date = pd_0050.loc[~pd_0050["etf_date"].isin(eval_date_range)]["etf_date"].max()
prev_date
# Out:
# '20180504'

# %%
from pyspark.sql.types import ArrayType, DoubleType, IntegerType
#計算上或下的值(udf)
def judge_up_down_pred_native(curr_price, prev_close_price):
    if checkNan(prev_close_price):
        return 0.0
    else:
        prev_price = prev_close_price
        if curr_price == prev_price:
            return 0.0
        elif curr_price > prev_price:
            return 1.0
        else:
            return 2.0
judge_up_down_pred=udf(judge_up_down_pred_native, DoubleType())

# %%
#declare previous row windows
wsSpec_etf = Window.partitionBy('etf_id').orderBy('etf_date') #time window for normal case
#eval dt for evluate score
tetf_dt_eval = tetfp_dt.filter(tetfp_dt.etf_date.isin([prev_date] + eval_date_range)) \
    .withColumn("prev_close", lag(tetfp_dt.etf_close).over(wsSpec_etf)) 
tetf_dt_eval =  tetf_dt_eval.withColumn("act_ud", judge_up_down_pred(tetf_dt_eval.etf_close, tetf_dt_eval.prev_close))
# tetf_dt_eval = tetf_dt_eval.filter(tetf_dt_eval.etf_date.isin(eval_date_range))
tetf_dt_eval.cache()
tetf_dt_eval.filter("etf_date = '20180507'").show()
# Out:
# +-------+--------+-----------------+--------+--------+-------+---------+---------+----------+------+
# | etf_id|etf_date|         etf_name|etf_open|etf_high|etf_low|etf_close|etf_count|prev_close|act_ud|
# +-------+--------+-----------------+--------+--------+-------+---------+---------+----------+------+
# |00701  |20180507|    國泰臺灣低波動30    |    20.9|    20.9|  20.71|    20.75|     36.0|     20.75|   0.0|
# |0051   |20180507| 元大中型100         |   31.96|   32.03|  31.88|     32.0|     16.0|      31.8|   1.0|
# |0057   |20180507| 富邦摩台            |    48.7|    48.7|  48.31|    48.63|     10.0|     48.46|   1.0|
# |006203 |20180507| 元大MSCI台灣        |   36.98|   36.98|  36.94|    36.94|      3.0|      36.7|   1.0|
# |0052   |20180507| 富邦科技            |   51.25|   51.25|   50.9|     51.0|     20.0|     51.15|   2.0|
# |0050   |20180507| 元大台灣50          |    79.5|   79.55|   78.8|     79.5|   3858.0|     78.95|   1.0|
# |0055   |20180507| 元大MSCI金融        |   17.18|   17.18|  17.03|     17.1|    113.0|     17.01|   1.0|
# |0054   |20180507| 元大台商50          |   23.14|   23.21|   23.1|    23.21|      3.0|     22.83|   1.0|
# |0059   |20180507| 富邦金融            |   41.83|    41.9|  41.83|     41.9|      2.0|     41.83|   1.0|
# |00690  |20180507| 兆豐藍籌30          |    21.6|    21.6|   21.5|     21.6|    292.0|     21.54|   1.0|
# |00713  |20180507|     元大台灣高息低波    |   30.31|   30.35|  30.25|    30.34|    245.0|      30.3|   1.0|
# |006204 |20180507|   永豐臺灣加權        |   52.75|   52.75|  52.65|    52.65|      2.0|      52.2|   1.0|
# |006208 |20180507|富邦台50            |   46.37|   46.58|  46.29|    46.58|     70.0|      45.9|   1.0|
# |0053   |20180507| 元大電子            |    34.5|   34.66|  34.25|    34.52|    127.0|     34.15|   1.0|
# |006201 |20180507| 元大富櫃50          |   13.42|   13.44|  13.37|    13.41|     23.0|     13.35|   1.0|
# |0056   |20180507|  元大高股息          |   25.35|   25.35|  25.17|     25.3|    952.0|      25.2|   1.0|
# |00692  |20180507|   富邦公司治理        |   20.89|   20.89|  20.74|    20.86|    961.0|     20.75|   1.0|
# |0058   |20180507| 富邦發達            |   45.44|   45.44|  45.44|    45.44|      1.0|     45.22|   1.0|
# +-------+--------+-----------------+--------+--------+-------+---------+---------+----------+------+

# %%
tetf_pd_eval = tetf_dt_eval.toPandas()
# tetf_pd_eval.loc[(tetf_pd_eval['etf_id'] == '006203 ') & (tetf_pd_eval['etf_date'] == '20180522')]['etf_close'].values[0]

# %%
from sklearn.metrics import accuracy_score, mean_squared_error, roc_auc_score
def doEvaluate(predict_res_final, tetf_pd_eval, next_date_range):
    etf_close_list = []
    act_ud_list = []
    prediction_list = []
    pred_ud_list = []
    acc_list = []
    weights = [0.1, 0.15, 0.2, 0.25, 0.3]
    judge_score = 0.0
    for row in predict_res_final:
        eid = row['etf_id']
        edate = row['etf_date']
        if edate not in next_date_range:
            continue
        etf_eval = tetf_pd_eval.loc[(tetf_pd_eval['etf_id'] == eid) & (tetf_pd_eval['etf_date'] == edate)]
        etf_close = etf_eval['etf_close'].values[0]
        act_ud = etf_eval['act_ud'].values[0]
        prediction = row['prediction']
        pred_ud = row['pred_ud']
        #etf score
        eidx = next_date_range.index(edate)
        judge_score = judge_score + \
            ((0.5 if pred_ud == act_ud else 0.0) + \
             ((etf_close-abs(prediction-etf_close))/etf_close)*0.5)*weights[eidx]
        etf_close_list.append(etf_close)
        act_ud_list.append(act_ud)
        prediction_list.append(prediction)
        pred_ud_list.append(pred_ud)
        acc_list.append(1.0 if pred_ud == act_ud else 0.0)
    #evaluate accuracy_score
    accuracy = accuracy_score(act_ud_list, pred_ud_list, normalize=True)
#     print(act_ud_list)
#     print(pred_ud_list)
    rmse = mean_squared_error(etf_close_list, prediction_list)
    return (rmse, accuracy, judge_score)

# %%
scaler_dic.keys()
# Out:
# dict_keys(['bias_3_6', 'bias_ma', 'close_dif', 'cmo', 'd', 'dif', 'ema10', 'ema10_slope', 'ema20', 'ema3', 'ema30', 'ema3_slope', 'ema5', 'ema5_slope', 'etf_close', 'k', 'macd1', 'macdhist1', 'macdsignal1', 'nbias20', 'nbias3', 'nbias6', 'ppo', 'rocr', 'rsi'])

# %%
def max_7percent(prev_close, prediction):
    dif = prediction - prev_close
    pct = 0.07
    dif_max = prev_close * pct
    rtn_val = prediction
    if abs(dif) > dif_max:
        if dif > 0:
            rtn_val = prev_close + dif_max
        else:
            rtn_val = prev_close - dif_max
    return rtn_val
        
def doPredict1(next_date_range, model1, etf_dic, next_pd_dic, scaler_dic, feature_cols, etf_ids):
    predict_res_final_1 = []
    dummy_date = '20999999'
    for date in next_date_range:
        for eid in etf_ids:
            #do predict
            pred_data = next_pd_dic[eid.strip()][feature_cols].values
            pred_res = model1.predict(data=pred_data)
#             print(pred_res)

            etf_dt = etf_dic[eid.strip()]
            prev_dt = etf_dt.loc[(etf_dt["etf_date"] < date) ].iloc[-1]
#             print('id of prev_dt: ', eid, ', date: ' ,prev_dt["etf_date"])
            prev_close = prev_dt["etf_close"]
            scaler = scaler_dic['close_dif']
            prediction = prev_close + scaler.inverse_transform(pred_res[0])[0][0]
            prediction = max_7percent(prev_close, prediction)
            #取出所有預測結果作合併，以進行後續成績計算
            predict_res_final_1.append({
                'etf_id': eid, 'etf_date': date,
                'prediction': prediction, 'pred_ud': judge_up_down_pred_native(prediction, prev_close)
            })

            if (date != next_date_range[-1]) and (date != dummy_date):
                #作出新的next_pd
                new_dic = {'etf_id': [eid], 'etf_date': [date], 'etf_name': [''], 
                           'etf_open': [0.0],  'etf_high': [0.0], 'etf_low': [0.0], 'etf_close': [prediction], 'etf_count': [0.0]}
                new_pd = pd.DataFrame(data=new_dic)[['etf_id','etf_date','etf_name', 'etf_open', 'etf_high', 
                                                          'etf_low', 'etf_close', 'etf_count']]
                #print(new_pd)
                etf_dt=etf_dt.append(new_pd, ignore_index=True)
                next_date = next_date_range[next_date_range.index(date)+1]
                etf_pd2, next_pd2, _ = create_feature(etf_dt, next_date, scaler_dic)
                etf_dic.update({eid.strip(): etf_dt})
                next_pd_dic.update({eid.strip(): next_pd2})
    return predict_res_final_1
    
def doPredict2(next_date_range, model2, etf_dic, next_pd_dic, scaler_dic, feature_cols, etf_ids):
    predict_res_final_2 = []
    for date in next_date_range:
        for eid in etf_ids:
            #do predict
            pred_data = next_pd_dic[eid.strip()][feature_cols].values
            pred_res = model2.predict(data=pred_data)
#             print(eid.strip(), '-', date, ': ', pred_res[0], '-', 
#                   scaler_dic[eid.strip()+'-etf_close'].inverse_transform(pred_res[0])[0][0])

            etf_dt = etf_dic[eid.strip()]
            prev_dt = etf_dt.loc[(etf_dt["etf_date"] < date) ].iloc[-1]
    #         print('id of prev_dt: ', eid, ', date: ' ,prev_dt["etf_date"])
            prev_close = prev_dt["etf_close"]
            scaler = scaler_dic['etf_close']
            prediction = scaler.inverse_transform(pred_res[0])[0][0]
            prediction = max_7percent(prev_close, prediction)
            #取出所有預測結果作合併，以進行後續成績計算
            predict_res_final_2.append({
                'etf_id': eid, 'etf_date': date,
                'prediction': prediction, 'pred_ud': judge_up_down_pred_native(prediction, prev_close)
            })

            if date != next_date_range[-1]:
                #作出新的next_pd
                new_dic = {'etf_id': [eid], 'etf_date': [date], 'etf_name': [''], 
                           'etf_open': [0.0],  'etf_high': [0.0], 'etf_low': [0.0], 'etf_close': [prediction], 'etf_count': [0.0]}
                new_pd = pd.DataFrame(data=new_dic)[['etf_id','etf_date','etf_name', 'etf_open', 'etf_high', 
                                                          'etf_low', 'etf_close', 'etf_count']]
                #print(new_pd)
                etf_dt=etf_dt.append(new_pd, ignore_index=True)
                next_date = next_date_range[next_date_range.index(date)+1]
                etf_pd2, next_pd2, _ = create_feature(etf_dt, next_date, scaler_dic)
                etf_dic.update({eid.strip(): etf_dt})
                next_pd_dic.update({eid.strip(): next_pd2})
    return predict_res_final_2

# %%
# for subset in itertools.combinations(feature_cols, 1):
#     print(list(subset))

# %%
#$$$
feature_date_dic = {
    'macd1,ema30,ema5_slope,macdsignal1,bias_3_6':'2-20180604',
    'ppo,ema20,ema3_slope,ema30,macdsignal1':'2-20180604',
    'ema30,ppo,ema5_slope,nbias3,ema10_slope':'2-20180604',
    'ppo,ema30,d,ema3_slope,macdhist1':'2-20180604',
    'ppo,ema30,nbias6,ema20,k':'2-20180604',
    'ema30,ppo,nbias6,ema20,macd1':'2-20180604',
    'ppo,ema30,ema10_slope,bias_ma,macdhist1':'2-20180604',
    'ema5_slope,ema30,macd1,ppo,bias_ma':'2-20180604',
    'ema5_slope,ema30,macd1,bias_ma,ema3_slope':'2-20180604',
    'ppo,ema20,nbias6,ema5_slope,macdsignal1':'2-20180604',
    'ppo,ema20,ema3_slope,ema30,ema10':'2-20180604',
    'ema5_slope,ema30,macd1,ppo,bias_3_6':'2-20180604',
    'ema30,ppo,nbias6,ema20,ema3_slope':'2-20180604',
    'macd1,ema30,ema5_slope,macdsignal1,bias_ma':'2-20180604',
    'ppo,ema30,d,ema3_slope,bias_3_6':'2-20180604',



    'nbias3,ema20,ema30,macdsignal1,rocr':'2-20180528',
    'ema20,rocr,nbias3,macdsignal1,k':'2-20180528',
    'ema20,rocr,nbias3,macdsignal1,ema10':'2-20180528',
    'ema20,rocr,nbias3,macdsignal1,dif':'2-20180528',
    'ema20,rocr,nbias3,macdsignal1,ema30':'2-20180528',
    'nbias3,ema20,ema30,macdsignal1,ema5_slope':'1-20180528',
    'nbias6,ema3_slope,macdsignal1,ema30,d':'2-20180528',
    'ema20,rocr,nbias3,ema3_slope,bias_ma':'2-20180528',
    'ema20,rocr,nbias3,ema3_slope,ema10_slope':'1-20180528',
    'ema20,rocr,ema3_slope,ema5_slope,bias_ma':'2-20180528',
    'ema20,rocr,nbias3,macdsignal1,bias_3_6':'2-20180528',
    'ema20,rocr,ema3_slope,ema5_slope,macdsignal1':'2-20180528',
    'ema20,rocr,nbias3,macdsignal1,ema5':'2-20180528',
    'ema20,rocr,d,ema3_slope,bias_ma':'2-20180528',
    'ema20,rocr,ema3_slope,nbias6,macdsignal1':'2-20180528',



    'ema30,ppo,rocr,macdsignal1,macd1':'2-20180521',
    'ema5,dif,nbias20,rocr,ema30':'2-20180521',
    'ema3,rocr,nbias20,dif,bias_ma':'2-20180521',
    'ema5,dif,nbias20,rocr,bias_ma':'2-20180521',
    'ema5,dif,nbias20,rocr,ema10':'2-20180521',
    'ema5,dif,nbias20,ema20,cmo':'2-20180521',
    'ema5,dif,nbias20,rocr,ema20':'2-20180521',
    'ema3,rocr,nbias20,dif,ema20':'2-20180521',
    'ema3,rocr,nbias20,dif,bias_3_6':'2-20180521',
    'ema3,rocr,nbias20,macdhist1,ema30':'1-20180521',
    'ema5,dif,nbias20,rocr,cmo':'2-20180521',
    'ema3,rsi,dif,ema20,d':'2-20180521',
    'ema10,rocr,d,nbias20,macdhist1':'1-20180521',
    'ema3,rocr,nbias20,dif,ema5':'2-20180521',
    'ema5,dif,nbias20,ema20,bias_3_6':'2-20180521',



    'k,ema30,ema5_slope,ema20,dif':'2-20180514',
    'ema3_slope,ema10,ema30,d,ppo':'2-20180514',
    'ema3_slope,ema20,dif,bias_3_6,ppo':'2-20180514',
    'ema3_slope,ema10,ema30,d,dif':'2-20180514',
    'ema3_slope,ema10,d,ema30,ema20':'2-20180514',
    'ema3_slope,ema20,dif,bias_3_6,macd1':'2-20180514',
    'ema3_slope,ema10,d,ema30,ppo':'2-20180514',
    'ema3_slope,ema10,ema30,d,macd1':'2-20180514',
    'ema3_slope,ema10,d,ema30,dif':'2-20180514',
    'ema3_slope,ema10,ppo,ema30,k':'2-20180514',
    'ema3_slope,ema10,ema30,dif,ppo':'2-20180514',
    'ema3_slope,ema20,d,ema10,ema30':'2-20180514',
    'ema3_slope,ema10,ema30,dif,nbias3':'2-20180514',
    'ema3_slope,ema10,ppo,nbias3,ema20':'2-20180514',
    'ema3_slope,ema10,ppo,nbias3,k':'2-20180514',



    'ema20,ema10_slope,nbias3,k,d':'2-20180507',
    'ema30,ema10_slope,ema3_slope,k,nbias3':'2-20180507',
    'ema10_slope,ema20,nbias3,ema3_slope,d':'2-20180507',
    'ema3_slope,ema10_slope,ema30,nbias3,macdhist1':'2-20180507',
    'ema10_slope,ema20,nbias3,ema3_slope,nbias6':'2-20180507',
    'ema3_slope,ema10_slope,ema20,nbias3,bias_ma':'2-20180507',
    'ema20,ema10_slope,ema3_slope,nbias3,bias_3_6':'2-20180507',
    'ema10_slope,ema20,ema3_slope,bias_3_6,ema30':'2-20180507',
    'ema10_slope,ema20,nbias3,rocr,k':'2-20180507',
    'ema10_slope,ema20,ema3_slope,bias_3_6,bias_ma':'2-20180507',
    'ema3_slope,ema10_slope,ema30,nbias3,ema20':'2-20180507',
    'ema10_slope,ema20,nbias3,ema3_slope,bias_3_6':'2-20180507',
    'ema30,ema10_slope,ema3_slope,k,ema5_slope':'2-20180507',
    'ema20,ema10_slope,nbias3,k,rocr':'2-20180507',
    'ema3_slope,ema10_slope,ema20,nbias3,ema5_slope':'2-20180507',
    
    'ema20,nbias6,ppo,macdhist1,ema30':'2-20180611',
    'ema30,bias_3_6,nbias3,d,nbias6':'2-20180611',
    'bias_3_6,ema30,bias_ma,ema5_slope,d':'2-20180611',
    'ema20,nbias6,nbias3,bias_3_6,macdhist1':'2-20180611',
    'bias_3_6,ema30,nbias6,bias_ma,d':'2-20180611',
    'bias_3_6,ema30,nbias6,bias_ma,nbias20':'2-20180611',
    'ema20,nbias6,ppo,bias_3_6,macdsignal1':'2-20180611',
    'bias_3_6,ema30,bias_ma,nbias6,ema20':'2-20180611',
    'ema20,nbias6,ppo,macdhist1,ema3_slope':'2-20180611',
    'bias_3_6,ema30,ema3_slope,nbias6,ema5_slope':'2-20180611',
    'ema20,nbias6,ppo,bias_3_6,macd1':'2-20180611',
    'bias_3_6,ema30,ema3_slope,nbias3,bias_ma':'2-20180611',
    'ema30,bias_3_6,nbias3,d,bias_ma':'2-20180611',
    'bias_3_6,ema30,nbias6,bias_ma,macdhist1':'2-20180611',
    'ema30,bias_3_6,nbias3,d,k':'2-20180611'
}
feature_dic = {}
f_date_dic = {}
for feature_str in feature_date_dic.keys():
    type_date = feature_date_dic[feature_str]
    type_date_seg = type_date.split('-')
    f_type = type_date_seg[0]
    f_date = type_date_seg[1]
    feature_dic.update({feature_str: f_type})
    f_date_dic.update({feature_str: f_date})

# %%
def train_and_eval(feature_dic, f_date_dic, etf_dic, train_dt, next_pd_dic, date_range, scaler_dic, etf_ids, tetf_pd_eval):    
    type_list = []
    feature_list = []
    acc_list = []
    rmse_list = []
    escore_list = []
    all_pred_list = []
    etf_pd_dic = {}
    predict_start_date = date_range[0]
    # for features in itertools.combinations(feature_cols, feature_num):
    for feature_str in feature_dic.keys():    
        f_type = feature_dic[feature_str]
        f_date = f_date_dic[feature_str]
        if f_date == predict_start_date:
            continue
        feature_cols = list(feature_str.split(','))
        model = trainModel(train_dt, feature_cols, f_type)
        #recover to re-run
        for eid in etf_ids:
            etf_dt = etf_dic[eid.strip()]
            etf_dt = etf_dt.loc[~etf_dt["etf_date"].isin(date_range)]
            etf_dic.update({eid.strip(): etf_dt})
            etf_pd, next_pd, _ = create_feature(etf_dic[eid.strip()], predict_start_date, scaler_dic)
    #         print(eid.strip(), ': ', etf_pd.shape)
            etf_pd_dic.update({eid.strip() : etf_pd})
            next_pd_dic.update({eid.strip() : next_pd})
        if f_type == '1':
            #evaluate close_dif
            predict_res_pd_1 = doPredict1(date_range, model, etf_dic, next_pd_dic, scaler_dic, feature_cols, etf_ids)
            all_pred_list = all_pred_list + predict_res_pd_1

            rmse1, acc1, e_score1 = doEvaluate(predict_res_pd_1, tetf_pd_eval, date_range)
            type_list.append("1")
            feature_list.append(feature_str)
            acc_list.append(acc1)
            rmse_list.append(rmse1)
            escore_list.append(e_score1)
            print(feature_str, ' f_date: ', f_date, ' pred_date: ', predict_start_date,' final1=', e_score1)
        else:
            #evaluate etf_close
            predict_res_pd_2 = doPredict2(date_range, model, etf_dic, next_pd_dic, scaler_dic, feature_cols, etf_ids)
            all_pred_list = all_pred_list + predict_res_pd_2

            rmse2, acc2, e_score2 = doEvaluate(predict_res_pd_2, tetf_pd_eval, date_range)
            type_list.append("2")
            feature_list.append(feature_str)
            acc_list.append(acc2)
            rmse_list.append(rmse2)
            escore_list.append(e_score2)
            print(feature_str, ' f_date: ', f_date, ' pred_date: ', predict_start_date,' final2=', e_score2)

    score_dic = {
        'feature_type' : type_list, 'feature': feature_list, 'accuracy': acc_list, 'rmse': rmse_list,
        'final_score': escore_list, 'pred_date': predict_start_date
    }
    
    return score_dic

def create_train_dt(train_etf_dic, date_range,etf_ids):
    etf_pd_dic = {}
    next_pd_dic = {}
    scaler_dic = {} #save minmax scaler
    predict_start_date = date_range[0]
    for etfid in etf_ids:
        etf_pd, next_pd, scalers = create_feature(train_etf_dic[etfid.strip()], predict_start_date, {})
        etf_pd_dic.update({etfid.strip() : etf_pd})
        next_pd_dic.update({etfid.strip() : next_pd})
        scaler_dic.update(scalers)
    train_dt_org = pd.concat([etf_pd_dic[etfid.strip()] for etfid in etf_ids])
    
    std_dic = {} # save reult of scaler
    for col in [c for c in train_dt_org.columns.values if c not in ["etf_id", "etf_date"]]:
            scaler_key = col
            if scaler_key in scaler_dic:
                scaler = scaler_dic[scaler_key]
                merged = list(itertools.chain.from_iterable(scaler.transform(train_dt_org[[col]])))                
            else:
                scaler = MinMaxScaler()
                merged = list(itertools.chain.from_iterable(scaler.fit_transform(train_dt_org[[col]])))
                #保留etf_close的scaler在後續使用
                scaler_dic.update({scaler_key: scaler})
            std_dic.update({col: merged})
    train_dt = pd.DataFrame(std_dic)
    print('train_dt count:', train_dt.shape)
    
    for etfid in etf_ids:
        std_dic = {}
        next_pd = next_pd_dic[etfid.strip()]
        for col in [c for c in next_pd.columns.values if c not in ["etf_id", "etf_date"]]:
            scaler = scaler_dic[col]
            merged = list(itertools.chain.from_iterable(scaler.transform(next_pd[[col]])))
            std_dic.update({col: merged})
        next_pd_dic.update({etfid.strip() : pd.DataFrame(std_dic)})
    print('next_pd_dic count:', len(next_pd_dic.keys()), '*' , next_pd_dic['0050'].shape)
    return (train_dt, next_pd_dic, scaler_dic)

# %%
score_pd = None
for date_range in train_date_range:
    train_etf_dic = {}
    for eid in etf_ids:
        end_train_date = date_range[0]
        etf_dt = etf_dic[eid.strip()]
        train_etf_dt = etf_dt.loc[(etf_dt['etf_id'] == eid) & (etf_dt['etf_date'] < end_train_date)]
        train_etf_dic.update({eid.strip(): train_etf_dt})
    train_dt, next_pd_dic, scaler_dic = create_train_dt(train_etf_dic, date_range, etf_ids)
    score_dic = train_and_eval(feature_dic, f_date_dic, train_etf_dic, train_dt, next_pd_dic, 
                                date_range, scaler_dic, etf_ids, tetf_pd_eval)
    if score_pd is None:
        score_pd = pd.DataFrame(data=score_dic)[['feature_type', 'feature', 'pred_date', 'accuracy', 'rmse', 'final_score']]
    else:
        tmp_pd = pd.DataFrame(data=score_dic)[['feature_type', 'feature', 'pred_date', 'accuracy', 'rmse', 'final_score']]
        score_pd = pd.concat([score_pd, tmp_pd])
# Out:
# train_dt count: (15531, 26)
# next_pd_dic count: 18 * (1, 26)
# macd1,ema30,ema5_slope,macdsignal1,bias_3_6  f_date:  20180604  pred_date:  20180507  final2= 13.939731514316309
# ppo,ema20,ema3_slope,ema30,macdsignal1  f_date:  20180604  pred_date:  20180507  final2= 13.646964491071815
# ema30,ppo,ema5_slope,nbias3,ema10_slope  f_date:  20180604  pred_date:  20180507  final2= 14.91823663867551
# ppo,ema30,d,ema3_slope,macdhist1  f_date:  20180604  pred_date:  20180507  final2= 12.18895066315619
# ppo,ema30,nbias6,ema20,k  f_date:  20180604  pred_date:  20180507  final2= 13.097849979282037
# ema30,ppo,nbias6,ema20,macd1  f_date:  20180604  pred_date:  20180507  final2= 14.336853683567098
# ppo,ema30,ema10_slope,bias_ma,macdhist1  f_date:  20180604  pred_date:  20180507  final2= 13.385576505689638
# ema5_slope,ema30,macd1,ppo,bias_ma  f_date:  20180604  pred_date:  20180507  final2= 14.547920924293795
# ema5_slope,ema30,macd1,bias_ma,ema3_slope  f_date:  20180604  pred_date:  20180507  final2= 14.18791823135761
# ppo,ema20,nbias6,ema5_slope,macdsignal1  f_date:  20180604  pred_date:  20180507  final2= 13.017543207714539
# ppo,ema20,ema3_slope,ema30,ema10  f_date:  20180604  pred_date:  20180507  final2= 14.09011086615664
# ema5_slope,ema30,macd1,ppo,bias_3_6  f_date:  20180604  pred_date:  20180507  final2= 13.941864737261625
# ema30,ppo,nbias6,ema20,ema3_slope  f_date:  20180604  pred_date:  20180507  final2= 14.398913614609043
# macd1,ema30,ema5_slope,macdsignal1,bias_ma  f_date:  20180604  pred_date:  20180507  final2= 14.209961418735972
# ppo,ema30,d,ema3_slope,bias_3_6  f_date:  20180604  pred_date:  20180507  final2= 13.775599408886423
# nbias3,ema20,ema30,macdsignal1,rocr  f_date:  20180528  pred_date:  20180507  final2= 14.752121714256075
# ema20,rocr,nbias3,macdsignal1,k  f_date:  20180528  pred_date:  20180507  final2= 14.408013163002446
# ema20,rocr,nbias3,macdsignal1,ema10  f_date:  20180528  pred_date:  20180507  final2= 14.547468558198407
# ema20,rocr,nbias3,macdsignal1,dif  f_date:  20180528  pred_date:  20180507  final2= 13.591886020203706
# ema20,rocr,nbias3,macdsignal1,ema30  f_date:  20180528  pred_date:  20180507  final2= 15.025594447196085
# nbias3,ema20,ema30,macdsignal1,ema5_slope  f_date:  20180528  pred_date:  20180507  final1= 12.914977645933703
# nbias6,ema3_slope,macdsignal1,ema30,d  f_date:  20180528  pred_date:  20180507  final2= 14.696017870536027
# ema20,rocr,nbias3,ema3_slope,bias_ma  f_date:  20180528  pred_date:  20180507  final2= 15.091394900712954
# ema20,rocr,nbias3,ema3_slope,ema10_slope  f_date:  20180528  pred_date:  20180507  final1= 14.255462933582942
# ema20,rocr,ema3_slope,ema5_slope,bias_ma  f_date:  20180528  pred_date:  20180507  final2= 15.047953181135327
# ema20,rocr,nbias3,macdsignal1,bias_3_6  f_date:  20180528  pred_date:  20180507  final2= 15.017864120263907
# ema20,rocr,ema3_slope,ema5_slope,macdsignal1  f_date:  20180528  pred_date:  20180507  final2= 14.5304935386933
# ema20,rocr,nbias3,macdsignal1,ema5  f_date:  20180528  pred_date:  20180507  final2= 14.789013893216737
# ema20,rocr,d,ema3_slope,bias_ma  f_date:  20180528  pred_date:  20180507  final2= 15.431849751726565
# ema20,rocr,ema3_slope,nbias6,macdsignal1  f_date:  20180528  pred_date:  20180507  final2= 14.537565338012616
# ema30,ppo,rocr,macdsignal1,macd1  f_date:  20180521  pred_date:  20180507  final2= 14.39431246238119
# ema5,dif,nbias20,rocr,ema30  f_date:  20180521  pred_date:  20180507  final2= 12.613379754028175
# ema3,rocr,nbias20,dif,bias_ma  f_date:  20180521  pred_date:  20180507  final2= 12.030157365223376
# ema5,dif,nbias20,rocr,bias_ma  f_date:  20180521  pred_date:  20180507  final2= 12.054960108335171
# ema5,dif,nbias20,rocr,ema10  f_date:  20180521  pred_date:  20180507  final2= 12.640861726700745
# ema5,dif,nbias20,ema20,cmo  f_date:  20180521  pred_date:  20180507  final2= 13.377390883291799
# ema5,dif,nbias20,rocr,ema20  f_date:  20180521  pred_date:  20180507  final2= 13.12311173625188
# ema3,rocr,nbias20,dif,ema20  f_date:  20180521  pred_date:  20180507  final2= 12.7521594480234
# ema3,rocr,nbias20,dif,bias_3_6  f_date:  20180521  pred_date:  20180507  final2= 12.79098116403285
# ema3,rocr,nbias20,macdhist1,ema30  f_date:  20180521  pred_date:  20180507  final1= 13.047583664129721
# ema5,dif,nbias20,rocr,cmo  f_date:  20180521  pred_date:  20180507  final2= 12.877880815183731
# ema3,rsi,dif,ema20,d  f_date:  20180521  pred_date:  20180507  final2= 13.076570376668526
# ema10,rocr,d,nbias20,macdhist1  f_date:  20180521  pred_date:  20180507  final1= 13.488698393524135
# ema3,rocr,nbias20,dif,ema5  f_date:  20180521  pred_date:  20180507  final2= 12.622222798435171
# ema5,dif,nbias20,ema20,bias_3_6  f_date:  20180521  pred_date:  20180507  final2= 12.897985964073253
# k,ema30,ema5_slope,ema20,dif  f_date:  20180514  pred_date:  20180507  final2= 13.855331688459543
# ema3_slope,ema10,ema30,d,ppo  f_date:  20180514  pred_date:  20180507  final2= 14.114823945695866
# ema3_slope,ema20,dif,bias_3_6,ppo  f_date:  20180514  pred_date:  20180507  final2= 14.742207920286194
# ema3_slope,ema10,ema30,d,dif  f_date:  20180514  pred_date:  20180507  final2= 13.411782874794438
# ema3_slope,ema10,d,ema30,ema20  f_date:  20180514  pred_date:  20180507  final2= 13.499081723497751
# ema3_slope,ema20,dif,bias_3_6,macd1  f_date:  20180514  pred_date:  20180507  final2= 13.616801836308586
# ema3_slope,ema10,d,ema30,ppo  f_date:  20180514  pred_date:  20180507  final2= 13.905412158449552
# ema3_slope,ema10,ema30,d,macd1  f_date:  20180514  pred_date:  20180507  final2= 14.471388715296774
# ema3_slope,ema10,d,ema30,dif  f_date:  20180514  pred_date:  20180507  final2= 14.190476282868605
# ema3_slope,ema10,ppo,ema30,k  f_date:  20180514  pred_date:  20180507  final2= 13.70633871003982
# ema3_slope,ema10,ema30,dif,ppo  f_date:  20180514  pred_date:  20180507  final2= 14.547816370996475
# ema3_slope,ema20,d,ema10,ema30  f_date:  20180514  pred_date:  20180507  final2= 14.373419619727919
# ema3_slope,ema10,ema30,dif,nbias3  f_date:  20180514  pred_date:  20180507  final2= 13.98148308641736
# ema3_slope,ema10,ppo,nbias3,ema20  f_date:  20180514  pred_date:  20180507  final2= 15.118223738219182
# ema3_slope,ema10,ppo,nbias3,k  f_date:  20180514  pred_date:  20180507  final2= 14.188698890629583
# ema20,nbias6,ppo,macdhist1,ema30  f_date:  20180611  pred_date:  20180507  final2= 12.585504258519077
# ema30,bias_3_6,nbias3,d,nbias6  f_date:  20180611  pred_date:  20180507  final2= 14.763754759006147
# bias_3_6,ema30,bias_ma,ema5_slope,d  f_date:  20180611  pred_date:  20180507  final2= 14.709999185293762
# ema20,nbias6,nbias3,bias_3_6,macdhist1  f_date:  20180611  pred_date:  20180507  final2= 14.605866898558613
# bias_3_6,ema30,nbias6,bias_ma,d  f_date:  20180611  pred_date:  20180507  final2= 14.528144114358135
# bias_3_6,ema30,nbias6,bias_ma,nbias20  f_date:  20180611  pred_date:  20180507  final2= 13.859732357953597
# ema20,nbias6,ppo,bias_3_6,macdsignal1  f_date:  20180611  pred_date:  20180507  final2= 13.719377478593112
# bias_3_6,ema30,bias_ma,nbias6,ema20  f_date:  20180611  pred_date:  20180507  final2= 15.755559109487843
# ema20,nbias6,ppo,macdhist1,ema3_slope  f_date:  20180611  pred_date:  20180507  final2= 13.271375612455934
# bias_3_6,ema30,ema3_slope,nbias6,ema5_slope  f_date:  20180611  pred_date:  20180507  final2= 14.684152599978683
# ema20,nbias6,ppo,bias_3_6,macd1  f_date:  20180611  pred_date:  20180507  final2= 14.236690450739575
# bias_3_6,ema30,ema3_slope,nbias3,bias_ma  f_date:  20180611  pred_date:  20180507  final2= 14.870615476400825
# ema30,bias_3_6,nbias3,d,bias_ma  f_date:  20180611  pred_date:  20180507  final2= 14.422363251984004
# bias_3_6,ema30,nbias6,bias_ma,macdhist1  f_date:  20180611  pred_date:  20180507  final2= 14.794115957752561
# ema30,bias_3_6,nbias3,d,k  f_date:  20180611  pred_date:  20180507  final2= 15.017599541668448
# train_dt count: (15621, 26)
# next_pd_dic count: 18 * (1, 26)
# macd1,ema30,ema5_slope,macdsignal1,bias_3_6  f_date:  20180604  pred_date:  20180514  final2= 12.961805751482922
# ppo,ema20,ema3_slope,ema30,macdsignal1  f_date:  20180604  pred_date:  20180514  final2= 13.641192795810975
# ema30,ppo,ema5_slope,nbias3,ema10_slope  f_date:  20180604  pred_date:  20180514  final2= 12.944652412407494
# ppo,ema30,d,ema3_slope,macdhist1  f_date:  20180604  pred_date:  20180514  final2= 13.35595843454093
# ppo,ema30,nbias6,ema20,k  f_date:  20180604  pred_date:  20180514  final2= 14.652858849313533
# ema30,ppo,nbias6,ema20,macd1  f_date:  20180604  pred_date:  20180514  final2= 14.260640323014188
# ppo,ema30,ema10_slope,bias_ma,macdhist1  f_date:  20180604  pred_date:  20180514  final2= 13.623977573169498
# ema5_slope,ema30,macd1,ppo,bias_ma  f_date:  20180604  pred_date:  20180514  final2= 13.821566086446143
# ema5_slope,ema30,macd1,bias_ma,ema3_slope  f_date:  20180604  pred_date:  20180514  final2= 13.103297637432581
# ppo,ema20,nbias6,ema5_slope,macdsignal1  f_date:  20180604  pred_date:  20180514  final2= 14.379033855370876
# ppo,ema20,ema3_slope,ema30,ema10  f_date:  20180604  pred_date:  20180514  final2= 14.158937081820367
# ema5_slope,ema30,macd1,ppo,bias_3_6  f_date:  20180604  pred_date:  20180514  final2= 13.706966698660212
# ema30,ppo,nbias6,ema20,ema3_slope  f_date:  20180604  pred_date:  20180514  final2= 14.330029170115607
# macd1,ema30,ema5_slope,macdsignal1,bias_ma  f_date:  20180604  pred_date:  20180514  final2= 13.841923308535597
# ppo,ema30,d,ema3_slope,bias_3_6  f_date:  20180604  pred_date:  20180514  final2= 13.96284008820804
# nbias3,ema20,ema30,macdsignal1,rocr  f_date:  20180528  pred_date:  20180514  final2= 13.027636849283452
# ema20,rocr,nbias3,macdsignal1,k  f_date:  20180528  pred_date:  20180514  final2= 13.290457726991342
# ema20,rocr,nbias3,macdsignal1,ema10  f_date:  20180528  pred_date:  20180514  final2= 12.947551953940382
# ema20,rocr,nbias3,macdsignal1,dif  f_date:  20180528  pred_date:  20180514  final2= 13.693751549638854
# ema20,rocr,nbias3,macdsignal1,ema30  f_date:  20180528  pred_date:  20180514  final2= 13.217709275162004
# nbias3,ema20,ema30,macdsignal1,ema5_slope  f_date:  20180528  pred_date:  20180514  final1= 12.864848617422494
# nbias6,ema3_slope,macdsignal1,ema30,d  f_date:  20180528  pred_date:  20180514  final2= 14.696605265348877
# ema20,rocr,nbias3,ema3_slope,bias_ma  f_date:  20180528  pred_date:  20180514  final2= 12.59071128378762
# ema20,rocr,nbias3,ema3_slope,ema10_slope  f_date:  20180528  pred_date:  20180514  final1= 12.437830473855277
# ema20,rocr,ema3_slope,ema5_slope,bias_ma  f_date:  20180528  pred_date:  20180514  final2= 12.313612391228322
# ema20,rocr,nbias3,macdsignal1,bias_3_6  f_date:  20180528  pred_date:  20180514  final2= 13.177605500267275
# ema20,rocr,ema3_slope,ema5_slope,macdsignal1  f_date:  20180528  pred_date:  20180514  final2= 13.571596602044218
# ema20,rocr,nbias3,macdsignal1,ema5  f_date:  20180528  pred_date:  20180514  final2= 12.351775922608148
# ema20,rocr,d,ema3_slope,bias_ma  f_date:  20180528  pred_date:  20180514  final2= 12.463659072799507
# ema20,rocr,ema3_slope,nbias6,macdsignal1  f_date:  20180528  pred_date:  20180514  final2= 13.614280594037167
# ema30,ppo,rocr,macdsignal1,macd1  f_date:  20180521  pred_date:  20180514  final2= 12.640182598008467
# ema5,dif,nbias20,rocr,ema30  f_date:  20180521  pred_date:  20180514  final2= 11.885945812539358
# ema3,rocr,nbias20,dif,bias_ma  f_date:  20180521  pred_date:  20180514  final2= 11.717219358302673
# ema5,dif,nbias20,rocr,bias_ma  f_date:  20180521  pred_date:  20180514  final2= 11.798005584035785
# ema5,dif,nbias20,rocr,ema10  f_date:  20180521  pred_date:  20180514  final2= 11.983621425571622
# ema5,dif,nbias20,ema20,cmo  f_date:  20180521  pred_date:  20180514  final2= 12.532310855332662
# ema5,dif,nbias20,rocr,ema20  f_date:  20180521  pred_date:  20180514  final2= 12.608171009620524
# ema3,rocr,nbias20,dif,ema20  f_date:  20180521  pred_date:  20180514  final2= 12.053404725566248
# ema3,rocr,nbias20,dif,bias_3_6  f_date:  20180521  pred_date:  20180514  final2= 12.085775076500592
# ema3,rocr,nbias20,macdhist1,ema30  f_date:  20180521  pred_date:  20180514  final1= 14.148683616531187
# ema5,dif,nbias20,rocr,cmo  f_date:  20180521  pred_date:  20180514  final2= 12.612446565705751
# ema3,rsi,dif,ema20,d  f_date:  20180521  pred_date:  20180514  final2= 12.761653401663153
# ema10,rocr,d,nbias20,macdhist1  f_date:  20180521  pred_date:  20180514  final1= 11.911851199845593
# ema3,rocr,nbias20,dif,ema5  f_date:  20180521  pred_date:  20180514  final2= 12.489567559266133
# ema5,dif,nbias20,ema20,bias_3_6  f_date:  20180521  pred_date:  20180514  final2= 12.885342366588162
# ema20,ema10_slope,nbias3,k,d  f_date:  20180507  pred_date:  20180514  final2= 12.149595613541166
# ema30,ema10_slope,ema3_slope,k,nbias3  f_date:  20180507  pred_date:  20180514  final2= 13.449521539746067
# ema10_slope,ema20,nbias3,ema3_slope,d  f_date:  20180507  pred_date:  20180514  final2= 12.415310341662552
# ema3_slope,ema10_slope,ema30,nbias3,macdhist1  f_date:  20180507  pred_date:  20180514  final2= 13.867442225653308
# ema10_slope,ema20,nbias3,ema3_slope,nbias6  f_date:  20180507  pred_date:  20180514  final2= 12.383585728999185
# ema3_slope,ema10_slope,ema20,nbias3,bias_ma  f_date:  20180507  pred_date:  20180514  final2= 12.031499654315278
# ema20,ema10_slope,ema3_slope,nbias3,bias_3_6  f_date:  20180507  pred_date:  20180514  final2= 12.557160954344653
# ema10_slope,ema20,ema3_slope,bias_3_6,ema30  f_date:  20180507  pred_date:  20180514  final2= 12.213515418969973
# ema10_slope,ema20,nbias3,rocr,k  f_date:  20180507  pred_date:  20180514  final2= 12.558102486187952
# ema10_slope,ema20,ema3_slope,bias_3_6,bias_ma  f_date:  20180507  pred_date:  20180514  final2= 12.823605460392736
# ema3_slope,ema10_slope,ema30,nbias3,ema20  f_date:  20180507  pred_date:  20180514  final2= 12.437949547763699
# ema10_slope,ema20,nbias3,ema3_slope,bias_3_6  f_date:  20180507  pred_date:  20180514  final2= 12.834078685594179
# ema30,ema10_slope,ema3_slope,k,ema5_slope  f_date:  20180507  pred_date:  20180514  final2= 12.22537832770446
# ema20,ema10_slope,nbias3,k,rocr  f_date:  20180507  pred_date:  20180514  final2= 12.735464946475199
# ema3_slope,ema10_slope,ema20,nbias3,ema5_slope  f_date:  20180507  pred_date:  20180514  final2= 12.490376657701642
# ema20,nbias6,ppo,macdhist1,ema30  f_date:  20180611  pred_date:  20180514  final2= 13.894945421879
# ema30,bias_3_6,nbias3,d,nbias6  f_date:  20180611  pred_date:  20180514  final2= 13.069464803229451
# bias_3_6,ema30,bias_ma,ema5_slope,d  f_date:  20180611  pred_date:  20180514  final2= 13.134954520409902
# ema20,nbias6,nbias3,bias_3_6,macdhist1  f_date:  20180611  pred_date:  20180514  final2= 13.426791777047391
# bias_3_6,ema30,nbias6,bias_ma,d  f_date:  20180611  pred_date:  20180514  final2= 13.12236302580533
# bias_3_6,ema30,nbias6,bias_ma,nbias20  f_date:  20180611  pred_date:  20180514  final2= 11.976649783583193
# ema20,nbias6,ppo,bias_3_6,macdsignal1  f_date:  20180611  pred_date:  20180514  final2= 13.40408629887805
# bias_3_6,ema30,bias_ma,nbias6,ema20  f_date:  20180611  pred_date:  20180514  final2= 14.267222199655567
# ema20,nbias6,ppo,macdhist1,ema3_slope  f_date:  20180611  pred_date:  20180514  final2= 13.964384541975726
# bias_3_6,ema30,ema3_slope,nbias6,ema5_slope  f_date:  20180611  pred_date:  20180514  final2= 12.660076707928106
# ema20,nbias6,ppo,bias_3_6,macd1  f_date:  20180611  pred_date:  20180514  final2= 14.705204327536851
# bias_3_6,ema30,ema3_slope,nbias3,bias_ma  f_date:  20180611  pred_date:  20180514  final2= 13.651319778696767
# ema30,bias_3_6,nbias3,d,bias_ma  f_date:  20180611  pred_date:  20180514  final2= 13.113818786767018
# bias_3_6,ema30,nbias6,bias_ma,macdhist1  f_date:  20180611  pred_date:  20180514  final2= 13.74646863985536
# ema30,bias_3_6,nbias3,d,k  f_date:  20180611  pred_date:  20180514  final2= 13.380799804602187
# train_dt count: (15711, 26)
# next_pd_dic count: 18 * (1, 26)
# macd1,ema30,ema5_slope,macdsignal1,bias_3_6  f_date:  20180604  pred_date:  20180521  final2= 13.039889011457204
# ppo,ema20,ema3_slope,ema30,macdsignal1  f_date:  20180604  pred_date:  20180521  final2= 13.476986946061526
# ema30,ppo,ema5_slope,nbias3,ema10_slope  f_date:  20180604  pred_date:  20180521  final2= 13.651392507414053
# ppo,ema30,d,ema3_slope,macdhist1  f_date:  20180604  pred_date:  20180521  final2= 13.207639137772308
# ppo,ema30,nbias6,ema20,k  f_date:  20180604  pred_date:  20180521  final2= 13.679946823515941
# ema30,ppo,nbias6,ema20,macd1  f_date:  20180604  pred_date:  20180521  final2= 13.491013857906598
# ppo,ema30,ema10_slope,bias_ma,macdhist1  f_date:  20180604  pred_date:  20180521  final2= 13.409732590045483
# ema5_slope,ema30,macd1,ppo,bias_ma  f_date:  20180604  pred_date:  20180521  final2= 13.169050876728798
# ema5_slope,ema30,macd1,bias_ma,ema3_slope  f_date:  20180604  pred_date:  20180521  final2= 13.800970819109939
# ppo,ema20,nbias6,ema5_slope,macdsignal1  f_date:  20180604  pred_date:  20180521  final2= 13.698326536767425
# ppo,ema20,ema3_slope,ema30,ema10  f_date:  20180604  pred_date:  20180521  final2= 13.136127979327142
# ema5_slope,ema30,macd1,ppo,bias_3_6  f_date:  20180604  pred_date:  20180521  final2= 13.48360111545434
# ema30,ppo,nbias6,ema20,ema3_slope  f_date:  20180604  pred_date:  20180521  final2= 14.356952520656735
# macd1,ema30,ema5_slope,macdsignal1,bias_ma  f_date:  20180604  pred_date:  20180521  final2= 13.187844864916817
# ppo,ema30,d,ema3_slope,bias_3_6  f_date:  20180604  pred_date:  20180521  final2= 14.157151633707008
# nbias3,ema20,ema30,macdsignal1,rocr  f_date:  20180528  pred_date:  20180521  final2= 12.384396902595064
# ema20,rocr,nbias3,macdsignal1,k  f_date:  20180528  pred_date:  20180521  final2= 12.540844218003507
# ema20,rocr,nbias3,macdsignal1,ema10  f_date:  20180528  pred_date:  20180521  final2= 12.544317896708005
# ema20,rocr,nbias3,macdsignal1,dif  f_date:  20180528  pred_date:  20180521  final2= 12.22490382368478
# ema20,rocr,nbias3,macdsignal1,ema30  f_date:  20180528  pred_date:  20180521  final2= 12.471873611754908
# nbias3,ema20,ema30,macdsignal1,ema5_slope  f_date:  20180528  pred_date:  20180521  final1= 13.232829279538052
# nbias6,ema3_slope,macdsignal1,ema30,d  f_date:  20180528  pred_date:  20180521  final2= 12.871620112911637
# ema20,rocr,nbias3,ema3_slope,bias_ma  f_date:  20180528  pred_date:  20180521  final2= 13.114776976908754
# ema20,rocr,nbias3,ema3_slope,ema10_slope  f_date:  20180528  pred_date:  20180521  final1= 13.573012424177072
# ema20,rocr,ema3_slope,ema5_slope,bias_ma  f_date:  20180528  pred_date:  20180521  final2= 12.922821497134324
# ema20,rocr,nbias3,macdsignal1,bias_3_6  f_date:  20180528  pred_date:  20180521  final2= 13.03240153812017
# ema20,rocr,ema3_slope,ema5_slope,macdsignal1  f_date:  20180528  pred_date:  20180521  final2= 12.603188965324794
# ema20,rocr,nbias3,macdsignal1,ema5  f_date:  20180528  pred_date:  20180521  final2= 12.977098239836918
# ema20,rocr,d,ema3_slope,bias_ma  f_date:  20180528  pred_date:  20180521  final2= 13.833131209401268
# ema20,rocr,ema3_slope,nbias6,macdsignal1  f_date:  20180528  pred_date:  20180521  final2= 13.143425750667282
# k,ema30,ema5_slope,ema20,dif  f_date:  20180514  pred_date:  20180521  final2= 12.98016218767764
# ema3_slope,ema10,ema30,d,ppo  f_date:  20180514  pred_date:  20180521  final2= 12.900771568112882
# ema3_slope,ema20,dif,bias_3_6,ppo  f_date:  20180514  pred_date:  20180521  final2= 12.92038175573614
# ema3_slope,ema10,ema30,d,dif  f_date:  20180514  pred_date:  20180521  final2= 12.764687365767521
# ema3_slope,ema10,d,ema30,ema20  f_date:  20180514  pred_date:  20180521  final2= 12.670944912173105
# ema3_slope,ema20,dif,bias_3_6,macd1  f_date:  20180514  pred_date:  20180521  final2= 12.916154973785012
# ema3_slope,ema10,d,ema30,ppo  f_date:  20180514  pred_date:  20180521  final2= 13.26800273162571
# ema3_slope,ema10,ema30,d,macd1  f_date:  20180514  pred_date:  20180521  final2= 12.793271417099149
# ema3_slope,ema10,d,ema30,dif  f_date:  20180514  pred_date:  20180521  final2= 12.561222013204942
# ema3_slope,ema10,ppo,ema30,k  f_date:  20180514  pred_date:  20180521  final2= 13.621657144089408
# ema3_slope,ema10,ema30,dif,ppo  f_date:  20180514  pred_date:  20180521  final2= 13.074272704866445
# ema3_slope,ema20,d,ema10,ema30  f_date:  20180514  pred_date:  20180521  final2= 13.336439986959967
# ema3_slope,ema10,ema30,dif,nbias3  f_date:  20180514  pred_date:  20180521  final2= 12.430702281469092
# ema3_slope,ema10,ppo,nbias3,ema20  f_date:  20180514  pred_date:  20180521  final2= 13.451850791798904
# ema3_slope,ema10,ppo,nbias3,k  f_date:  20180514  pred_date:  20180521  final2= 13.308335747974253
# ema20,ema10_slope,nbias3,k,d  f_date:  20180507  pred_date:  20180521  final2= 12.676339004281273
# ema30,ema10_slope,ema3_slope,k,nbias3  f_date:  20180507  pred_date:  20180521  final2= 13.407778260929849
# ema10_slope,ema20,nbias3,ema3_slope,d  f_date:  20180507  pred_date:  20180521  final2= 12.936980969025779
# ema3_slope,ema10_slope,ema30,nbias3,macdhist1  f_date:  20180507  pred_date:  20180521  final2= 13.36400342192293
# ema10_slope,ema20,nbias3,ema3_slope,nbias6  f_date:  20180507  pred_date:  20180521  final2= 13.848362615013196
# ema3_slope,ema10_slope,ema20,nbias3,bias_ma  f_date:  20180507  pred_date:  20180521  final2= 13.488364340643088
# ema20,ema10_slope,ema3_slope,nbias3,bias_3_6  f_date:  20180507  pred_date:  20180521  final2= 13.86808751649823
# ema10_slope,ema20,ema3_slope,bias_3_6,ema30  f_date:  20180507  pred_date:  20180521  final2= 13.851390059076598
# ema10_slope,ema20,nbias3,rocr,k  f_date:  20180507  pred_date:  20180521  final2= 13.965104753105633
# ema10_slope,ema20,ema3_slope,bias_3_6,bias_ma  f_date:  20180507  pred_date:  20180521  final2= 13.144680729464953
# ema3_slope,ema10_slope,ema30,nbias3,ema20  f_date:  20180507  pred_date:  20180521  final2= 13.106919540001924
# ema10_slope,ema20,nbias3,ema3_slope,bias_3_6  f_date:  20180507  pred_date:  20180521  final2= 13.474771906948012
# ema30,ema10_slope,ema3_slope,k,ema5_slope  f_date:  20180507  pred_date:  20180521  final2= 14.580388456102467
# ema20,ema10_slope,nbias3,k,rocr  f_date:  20180507  pred_date:  20180521  final2= 13.231511309110926
# ema3_slope,ema10_slope,ema20,nbias3,ema5_slope  f_date:  20180507  pred_date:  20180521  final2= 14.213344747238548
# ema20,nbias6,ppo,macdhist1,ema30  f_date:  20180611  pred_date:  20180521  final2= 13.696035677429808
# ema30,bias_3_6,nbias3,d,nbias6  f_date:  20180611  pred_date:  20180521  final2= 13.208851993798882
# bias_3_6,ema30,bias_ma,ema5_slope,d  f_date:  20180611  pred_date:  20180521  final2= 12.715212303959792
# ema20,nbias6,nbias3,bias_3_6,macdhist1  f_date:  20180611  pred_date:  20180521  final2= 14.287559387030099
# bias_3_6,ema30,nbias6,bias_ma,d  f_date:  20180611  pred_date:  20180521  final2= 13.422849974867416
# bias_3_6,ema30,nbias6,bias_ma,nbias20  f_date:  20180611  pred_date:  20180521  final2= 13.641289859680796
# ema20,nbias6,ppo,bias_3_6,macdsignal1  f_date:  20180611  pred_date:  20180521  final2= 13.422960329438764
# bias_3_6,ema30,bias_ma,nbias6,ema20  f_date:  20180611  pred_date:  20180521  final2= 12.05795964967535
# ema20,nbias6,ppo,macdhist1,ema3_slope  f_date:  20180611  pred_date:  20180521  final2= 13.733839640311182
# bias_3_6,ema30,ema3_slope,nbias6,ema5_slope  f_date:  20180611  pred_date:  20180521  final2= 12.564357289355828
# ema20,nbias6,ppo,bias_3_6,macd1  f_date:  20180611  pred_date:  20180521  final2= 13.674507779464149
# bias_3_6,ema30,ema3_slope,nbias3,bias_ma  f_date:  20180611  pred_date:  20180521  final2= 12.966068155921953
# ema30,bias_3_6,nbias3,d,bias_ma  f_date:  20180611  pred_date:  20180521  final2= 11.853260251504445
# bias_3_6,ema30,nbias6,bias_ma,macdhist1  f_date:  20180611  pred_date:  20180521  final2= 12.537966531721509
# ema30,bias_3_6,nbias3,d,k  f_date:  20180611  pred_date:  20180521  final2= 12.4451184260932
# train_dt count: (15801, 26)
# next_pd_dic count: 18 * (1, 26)
# macd1,ema30,ema5_slope,macdsignal1,bias_3_6  f_date:  20180604  pred_date:  20180528  final2= 13.416950048133142
# ppo,ema20,ema3_slope,ema30,macdsignal1  f_date:  20180604  pred_date:  20180528  final2= 12.965776053618747
# ema30,ppo,ema5_slope,nbias3,ema10_slope  f_date:  20180604  pred_date:  20180528  final2= 12.67317140602013
# ppo,ema30,d,ema3_slope,macdhist1  f_date:  20180604  pred_date:  20180528  final2= 13.065966736659526
# ppo,ema30,nbias6,ema20,k  f_date:  20180604  pred_date:  20180528  final2= 12.71618628406279
# ema30,ppo,nbias6,ema20,macd1  f_date:  20180604  pred_date:  20180528  final2= 12.804114883601866
# ppo,ema30,ema10_slope,bias_ma,macdhist1  f_date:  20180604  pred_date:  20180528  final2= 13.804124269488577
# ema5_slope,ema30,macd1,ppo,bias_ma  f_date:  20180604  pred_date:  20180528  final2= 13.177234200629217
# ema5_slope,ema30,macd1,bias_ma,ema3_slope  f_date:  20180604  pred_date:  20180528  final2= 12.881909875317563
# ppo,ema20,nbias6,ema5_slope,macdsignal1  f_date:  20180604  pred_date:  20180528  final2= 12.891074485935523
# ppo,ema20,ema3_slope,ema30,ema10  f_date:  20180604  pred_date:  20180528  final2= 14.020298075072482
# ema5_slope,ema30,macd1,ppo,bias_3_6  f_date:  20180604  pred_date:  20180528  final2= 13.510565376771599
# ema30,ppo,nbias6,ema20,ema3_slope  f_date:  20180604  pred_date:  20180528  final2= 12.523459431759647
# macd1,ema30,ema5_slope,macdsignal1,bias_ma  f_date:  20180604  pred_date:  20180528  final2= 13.58901892096084
# ppo,ema30,d,ema3_slope,bias_3_6  f_date:  20180604  pred_date:  20180528  final2= 13.129194419540278
# ema30,ppo,rocr,macdsignal1,macd1  f_date:  20180521  pred_date:  20180528  final2= 14.480479010697131
# ema5,dif,nbias20,rocr,ema30  f_date:  20180521  pred_date:  20180528  final2= 14.435496206174964
# ema3,rocr,nbias20,dif,bias_ma  f_date:  20180521  pred_date:  20180528  final2= 13.42305676693488
# ema5,dif,nbias20,rocr,bias_ma  f_date:  20180521  pred_date:  20180528  final2= 13.691582558207758
# ema5,dif,nbias20,rocr,ema10  f_date:  20180521  pred_date:  20180528  final2= 13.84001299147237
# ema5,dif,nbias20,ema20,cmo  f_date:  20180521  pred_date:  20180528  final2= 13.508356770639958
# ema5,dif,nbias20,rocr,ema20  f_date:  20180521  pred_date:  20180528  final2= 13.682202141234384
# ema3,rocr,nbias20,dif,ema20  f_date:  20180521  pred_date:  20180528  final2= 13.350598153670218
# ema3,rocr,nbias20,dif,bias_3_6  f_date:  20180521  pred_date:  20180528  final2= 13.78362638907525
# ema3,rocr,nbias20,macdhist1,ema30  f_date:  20180521  pred_date:  20180528  final1= 12.88851640194424
# ema5,dif,nbias20,rocr,cmo  f_date:  20180521  pred_date:  20180528  final2= 14.16934509668902
# ema3,rsi,dif,ema20,d  f_date:  20180521  pred_date:  20180528  final2= 13.354074660190077
# ema10,rocr,d,nbias20,macdhist1  f_date:  20180521  pred_date:  20180528  final1= 13.854867281037212
# ema3,rocr,nbias20,dif,ema5  f_date:  20180521  pred_date:  20180528  final2= 14.25864085838904
# ema5,dif,nbias20,ema20,bias_3_6  f_date:  20180521  pred_date:  20180528  final2= 13.68825397740728
# k,ema30,ema5_slope,ema20,dif  f_date:  20180514  pred_date:  20180528  final2= 12.70589790302201
# ema3_slope,ema10,ema30,d,ppo  f_date:  20180514  pred_date:  20180528  final2= 14.240760092040352
# ema3_slope,ema20,dif,bias_3_6,ppo  f_date:  20180514  pred_date:  20180528  final2= 13.377889009730396
# ema3_slope,ema10,ema30,d,dif  f_date:  20180514  pred_date:  20180528  final2= 13.3279566844146
# ema3_slope,ema10,d,ema30,ema20  f_date:  20180514  pred_date:  20180528  final2= 13.680841722318911
# ema3_slope,ema20,dif,bias_3_6,macd1  f_date:  20180514  pred_date:  20180528  final2= 13.417586610580084
# ema3_slope,ema10,d,ema30,ppo  f_date:  20180514  pred_date:  20180528  final2= 14.353572205250716
# ema3_slope,ema10,ema30,d,macd1  f_date:  20180514  pred_date:  20180528  final2= 13.051656691791127
# ema3_slope,ema10,d,ema30,dif  f_date:  20180514  pred_date:  20180528  final2= 13.907567054016935
# ema3_slope,ema10,ppo,ema30,k  f_date:  20180514  pred_date:  20180528  final2= 13.323511363483764
# ema3_slope,ema10,ema30,dif,ppo  f_date:  20180514  pred_date:  20180528  final2= 13.576950118626916
# ema3_slope,ema20,d,ema10,ema30  f_date:  20180514  pred_date:  20180528  final2= 13.921804079435423
# ema3_slope,ema10,ema30,dif,nbias3  f_date:  20180514  pred_date:  20180528  final2= 13.861015860896666
# ema3_slope,ema10,ppo,nbias3,ema20  f_date:  20180514  pred_date:  20180528  final2= 13.697444824575783
# ema3_slope,ema10,ppo,nbias3,k  f_date:  20180514  pred_date:  20180528  final2= 13.599005090042423
# ema20,ema10_slope,nbias3,k,d  f_date:  20180507  pred_date:  20180528  final2= 13.664601043285378
# ema30,ema10_slope,ema3_slope,k,nbias3  f_date:  20180507  pred_date:  20180528  final2= 12.352530377351199
# ema10_slope,ema20,nbias3,ema3_slope,d  f_date:  20180507  pred_date:  20180528  final2= 13.32814479091142
# ema3_slope,ema10_slope,ema30,nbias3,macdhist1  f_date:  20180507  pred_date:  20180528  final2= 13.14389592747742
# ema10_slope,ema20,nbias3,ema3_slope,nbias6  f_date:  20180507  pred_date:  20180528  final2= 13.048482515126313
# ema3_slope,ema10_slope,ema20,nbias3,bias_ma  f_date:  20180507  pred_date:  20180528  final2= 12.725247652883276
# ema20,ema10_slope,ema3_slope,nbias3,bias_3_6  f_date:  20180507  pred_date:  20180528  final2= 13.452517574619483
# ema10_slope,ema20,ema3_slope,bias_3_6,ema30  f_date:  20180507  pred_date:  20180528  final2= 12.857385806027182
# ema10_slope,ema20,nbias3,rocr,k  f_date:  20180507  pred_date:  20180528  final2= 13.68910472814622
# ema10_slope,ema20,ema3_slope,bias_3_6,bias_ma  f_date:  20180507  pred_date:  20180528  final2= 13.095499613353565
# ema3_slope,ema10_slope,ema30,nbias3,ema20  f_date:  20180507  pred_date:  20180528  final2= 13.062076753298692
# ema10_slope,ema20,nbias3,ema3_slope,bias_3_6  f_date:  20180507  pred_date:  20180528  final2= 13.390391947099584
# ema30,ema10_slope,ema3_slope,k,ema5_slope  f_date:  20180507  pred_date:  20180528  final2= 13.449370151110436
# ema20,ema10_slope,nbias3,k,rocr  f_date:  20180507  pred_date:  20180528  final2= 12.71768878966168
# ema3_slope,ema10_slope,ema20,nbias3,ema5_slope  f_date:  20180507  pred_date:  20180528  final2= 13.579742078711778
# ema20,nbias6,ppo,macdhist1,ema30  f_date:  20180611  pred_date:  20180528  final2= 12.649247347026426
# ema30,bias_3_6,nbias3,d,nbias6  f_date:  20180611  pred_date:  20180528  final2= 14.350672599788961
# bias_3_6,ema30,bias_ma,ema5_slope,d  f_date:  20180611  pred_date:  20180528  final2= 12.949010696785907
# ema20,nbias6,nbias3,bias_3_6,macdhist1  f_date:  20180611  pred_date:  20180528  final2= 13.967631861749053
# bias_3_6,ema30,nbias6,bias_ma,d  f_date:  20180611  pred_date:  20180528  final2= 12.66742207258051
# bias_3_6,ema30,nbias6,bias_ma,nbias20  f_date:  20180611  pred_date:  20180528  final2= 12.79414137183961
# ema20,nbias6,ppo,bias_3_6,macdsignal1  f_date:  20180611  pred_date:  20180528  final2= 12.9309185824393
# bias_3_6,ema30,bias_ma,nbias6,ema20  f_date:  20180611  pred_date:  20180528  final2= 13.061727867343157
# ema20,nbias6,ppo,macdhist1,ema3_slope  f_date:  20180611  pred_date:  20180528  final2= 12.58716230266971
# bias_3_6,ema30,ema3_slope,nbias6,ema5_slope  f_date:  20180611  pred_date:  20180528  final2= 12.664333585554106
# ema20,nbias6,ppo,bias_3_6,macd1  f_date:  20180611  pred_date:  20180528  final2= 13.430824542054372
# bias_3_6,ema30,ema3_slope,nbias3,bias_ma  f_date:  20180611  pred_date:  20180528  final2= 12.711660903698238
# ema30,bias_3_6,nbias3,d,bias_ma  f_date:  20180611  pred_date:  20180528  final2= 12.395172003082646
# bias_3_6,ema30,nbias6,bias_ma,macdhist1  f_date:  20180611  pred_date:  20180528  final2= 12.769506071960091
# ema30,bias_3_6,nbias3,d,k  f_date:  20180611  pred_date:  20180528  final2= 13.154173137046923
# train_dt count: (15891, 26)
# next_pd_dic count: 18 * (1, 26)
# nbias3,ema20,ema30,macdsignal1,rocr  f_date:  20180528  pred_date:  20180604  final2= 13.71322392038367
# ema20,rocr,nbias3,macdsignal1,k  f_date:  20180528  pred_date:  20180604  final2= 13.376796754413657
# ema20,rocr,nbias3,macdsignal1,ema10  f_date:  20180528  pred_date:  20180604  final2= 13.195904939230306
# ema20,rocr,nbias3,macdsignal1,dif  f_date:  20180528  pred_date:  20180604  final2= 13.054954333380804
# ema20,rocr,nbias3,macdsignal1,ema30  f_date:  20180528  pred_date:  20180604  final2= 12.714475957388846
# nbias3,ema20,ema30,macdsignal1,ema5_slope  f_date:  20180528  pred_date:  20180604  final1= 13.5739496550377
# nbias6,ema3_slope,macdsignal1,ema30,d  f_date:  20180528  pred_date:  20180604  final2= 14.327449509364541
# ema20,rocr,nbias3,ema3_slope,bias_ma  f_date:  20180528  pred_date:  20180604  final2= 13.171555968146142
# ema20,rocr,nbias3,ema3_slope,ema10_slope  f_date:  20180528  pred_date:  20180604  final1= 12.740618738276046
# ema20,rocr,ema3_slope,ema5_slope,bias_ma  f_date:  20180528  pred_date:  20180604  final2= 12.123622824949125
# ema20,rocr,nbias3,macdsignal1,bias_3_6  f_date:  20180528  pred_date:  20180604  final2= 13.869571522294684
# ema20,rocr,ema3_slope,ema5_slope,macdsignal1  f_date:  20180528  pred_date:  20180604  final2= 13.795111856639512
# ema20,rocr,nbias3,macdsignal1,ema5  f_date:  20180528  pred_date:  20180604  final2= 13.36544066021406
# ema20,rocr,d,ema3_slope,bias_ma  f_date:  20180528  pred_date:  20180604  final2= 13.316104323529068
# ema20,rocr,ema3_slope,nbias6,macdsignal1  f_date:  20180528  pred_date:  20180604  final2= 14.099993916837981
# ema30,ppo,rocr,macdsignal1,macd1  f_date:  20180521  pred_date:  20180604  final2= 13.247165154605316
# ema5,dif,nbias20,rocr,ema30  f_date:  20180521  pred_date:  20180604  final2= 12.829706716692405
# ema3,rocr,nbias20,dif,bias_ma  f_date:  20180521  pred_date:  20180604  final2= 12.827299766677175
# ema5,dif,nbias20,rocr,bias_ma  f_date:  20180521  pred_date:  20180604  final2= 13.000340021703021
# ema5,dif,nbias20,rocr,ema10  f_date:  20180521  pred_date:  20180604  final2= 12.72283798997951
# ema5,dif,nbias20,ema20,cmo  f_date:  20180521  pred_date:  20180604  final2= 13.571183985205375
# ema5,dif,nbias20,rocr,ema20  f_date:  20180521  pred_date:  20180604  final2= 13.397316051812957
# ema3,rocr,nbias20,dif,ema20  f_date:  20180521  pred_date:  20180604  final2= 13.349254082359836
# ema3,rocr,nbias20,dif,bias_3_6  f_date:  20180521  pred_date:  20180604  final2= 12.553278476304808
# ema3,rocr,nbias20,macdhist1,ema30  f_date:  20180521  pred_date:  20180604  final1= 13.310503762084387
# ema5,dif,nbias20,rocr,cmo  f_date:  20180521  pred_date:  20180604  final2= 13.281814452831195
# ema3,rsi,dif,ema20,d  f_date:  20180521  pred_date:  20180604  final2= 13.823741436130176
# ema10,rocr,d,nbias20,macdhist1  f_date:  20180521  pred_date:  20180604  final1= 13.322971516105222
# ema3,rocr,nbias20,dif,ema5  f_date:  20180521  pred_date:  20180604  final2= 13.022370506459405
# ema5,dif,nbias20,ema20,bias_3_6  f_date:  20180521  pred_date:  20180604  final2= 13.08342935959566
# k,ema30,ema5_slope,ema20,dif  f_date:  20180514  pred_date:  20180604  final2= 13.403804253684289
# ema3_slope,ema10,ema30,d,ppo  f_date:  20180514  pred_date:  20180604  final2= 14.253642463628692
# ema3_slope,ema20,dif,bias_3_6,ppo  f_date:  20180514  pred_date:  20180604  final2= 13.363653022595559
# ema3_slope,ema10,ema30,d,dif  f_date:  20180514  pred_date:  20180604  final2= 14.122598479551437
# ema3_slope,ema10,d,ema30,ema20  f_date:  20180514  pred_date:  20180604  final2= 14.074992452241563
# ema3_slope,ema20,dif,bias_3_6,macd1  f_date:  20180514  pred_date:  20180604  final2= 13.614335742696543
# ema3_slope,ema10,d,ema30,ppo  f_date:  20180514  pred_date:  20180604  final2= 14.514042761431433
# ema3_slope,ema10,ema30,d,macd1  f_date:  20180514  pred_date:  20180604  final2= 14.506994769551055
# ema3_slope,ema10,d,ema30,dif  f_date:  20180514  pred_date:  20180604  final2= 14.60175187728376
# ema3_slope,ema10,ppo,ema30,k  f_date:  20180514  pred_date:  20180604  final2= 14.164083724977074
# ema3_slope,ema10,ema30,dif,ppo  f_date:  20180514  pred_date:  20180604  final2= 13.702308156119702
# ema3_slope,ema20,d,ema10,ema30  f_date:  20180514  pred_date:  20180604  final2= 13.561804716390643
# ema3_slope,ema10,ema30,dif,nbias3  f_date:  20180514  pred_date:  20180604  final2= 14.082902523658836
# ema3_slope,ema10,ppo,nbias3,ema20  f_date:  20180514  pred_date:  20180604  final2= 13.26554594647903
# ema3_slope,ema10,ppo,nbias3,k  f_date:  20180514  pred_date:  20180604  final2= 14.179856283080337
# ema20,ema10_slope,nbias3,k,d  f_date:  20180507  pred_date:  20180604  final2= 12.051222254550796
# ema30,ema10_slope,ema3_slope,k,nbias3  f_date:  20180507  pred_date:  20180604  final2= 12.539345213815004
# ema10_slope,ema20,nbias3,ema3_slope,d  f_date:  20180507  pred_date:  20180604  final2= 12.427481850549222
# ema3_slope,ema10_slope,ema30,nbias3,macdhist1  f_date:  20180507  pred_date:  20180604  final2= 13.501388953296043
# ema10_slope,ema20,nbias3,ema3_slope,nbias6  f_date:  20180507  pred_date:  20180604  final2= 12.924896108066186
# ema3_slope,ema10_slope,ema20,nbias3,bias_ma  f_date:  20180507  pred_date:  20180604  final2= 12.505561551150583
# ema20,ema10_slope,ema3_slope,nbias3,bias_3_6  f_date:  20180507  pred_date:  20180604  final2= 13.376030927547152
# ema10_slope,ema20,ema3_slope,bias_3_6,ema30  f_date:  20180507  pred_date:  20180604  final2= 12.881913598267586
# ema10_slope,ema20,nbias3,rocr,k  f_date:  20180507  pred_date:  20180604  final2= 12.251284086649179
# ema10_slope,ema20,ema3_slope,bias_3_6,bias_ma  f_date:  20180507  pred_date:  20180604  final2= 12.647441045776626
# ema3_slope,ema10_slope,ema30,nbias3,ema20  f_date:  20180507  pred_date:  20180604  final2= 12.73108700963488
# ema10_slope,ema20,nbias3,ema3_slope,bias_3_6  f_date:  20180507  pred_date:  20180604  final2= 13.086994492778157
# ema30,ema10_slope,ema3_slope,k,ema5_slope  f_date:  20180507  pred_date:  20180604  final2= 13.347205887005348
# ema20,ema10_slope,nbias3,k,rocr  f_date:  20180507  pred_date:  20180604  final2= 13.094406731387311
# ema3_slope,ema10_slope,ema20,nbias3,ema5_slope  f_date:  20180507  pred_date:  20180604  final2= 12.464952746069665
# ema20,nbias6,ppo,macdhist1,ema30  f_date:  20180611  pred_date:  20180604  final2= 13.603128273568252
# ema30,bias_3_6,nbias3,d,nbias6  f_date:  20180611  pred_date:  20180604  final2= 12.90017328148278
# bias_3_6,ema30,bias_ma,ema5_slope,d  f_date:  20180611  pred_date:  20180604  final2= 13.426206394477708
# ema20,nbias6,nbias3,bias_3_6,macdhist1  f_date:  20180611  pred_date:  20180604  final2= 13.49919326907293
# bias_3_6,ema30,nbias6,bias_ma,d  f_date:  20180611  pred_date:  20180604  final2= 13.433354601101357
# bias_3_6,ema30,nbias6,bias_ma,nbias20  f_date:  20180611  pred_date:  20180604  final2= 13.101859535044456
# ema20,nbias6,ppo,bias_3_6,macdsignal1  f_date:  20180611  pred_date:  20180604  final2= 14.013775441340304
# bias_3_6,ema30,bias_ma,nbias6,ema20  f_date:  20180611  pred_date:  20180604  final2= 13.318028819448486
# ema20,nbias6,ppo,macdhist1,ema3_slope  f_date:  20180611  pred_date:  20180604  final2= 14.602746494238232
# bias_3_6,ema30,ema3_slope,nbias6,ema5_slope  f_date:  20180611  pred_date:  20180604  final2= 12.438843454587397
# ema20,nbias6,ppo,bias_3_6,macd1  f_date:  20180611  pred_date:  20180604  final2= 13.981352567779679
# bias_3_6,ema30,ema3_slope,nbias3,bias_ma  f_date:  20180611  pred_date:  20180604  final2= 12.549644514368177
# ema30,bias_3_6,nbias3,d,bias_ma  f_date:  20180611  pred_date:  20180604  final2= 12.222382109316507
# bias_3_6,ema30,nbias6,bias_ma,macdhist1  f_date:  20180611  pred_date:  20180604  final2= 12.940659490516115
# ema30,bias_3_6,nbias3,d,k  f_date:  20180611  pred_date:  20180604  final2= 13.586380450167997
# train_dt count: (15981, 26)
# next_pd_dic count: 18 * (1, 26)
# macd1,ema30,ema5_slope,macdsignal1,bias_3_6  f_date:  20180604  pred_date:  20180611  final2= 14.649155958947752
# ppo,ema20,ema3_slope,ema30,macdsignal1  f_date:  20180604  pred_date:  20180611  final2= 13.264110850239424
# ema30,ppo,ema5_slope,nbias3,ema10_slope  f_date:  20180604  pred_date:  20180611  final2= 14.039437666082442
# ppo,ema30,d,ema3_slope,macdhist1  f_date:  20180604  pred_date:  20180611  final2= 13.251723271795381
# ppo,ema30,nbias6,ema20,k  f_date:  20180604  pred_date:  20180611  final2= 13.244202781553264
# ema30,ppo,nbias6,ema20,macd1  f_date:  20180604  pred_date:  20180611  final2= 14.500926820262167
# ppo,ema30,ema10_slope,bias_ma,macdhist1  f_date:  20180604  pred_date:  20180611  final2= 13.05524723561256
# ema5_slope,ema30,macd1,ppo,bias_ma  f_date:  20180604  pred_date:  20180611  final2= 14.03780654275173
# ema5_slope,ema30,macd1,bias_ma,ema3_slope  f_date:  20180604  pred_date:  20180611  final2= 13.346733274903244
# ppo,ema20,nbias6,ema5_slope,macdsignal1  f_date:  20180604  pred_date:  20180611  final2= 14.312277589383852
# ppo,ema20,ema3_slope,ema30,ema10  f_date:  20180604  pred_date:  20180611  final2= 12.639969901755368
# ema5_slope,ema30,macd1,ppo,bias_3_6  f_date:  20180604  pred_date:  20180611  final2= 14.198801138619812
# ema30,ppo,nbias6,ema20,ema3_slope  f_date:  20180604  pred_date:  20180611  final2= 14.022473375045566
# macd1,ema30,ema5_slope,macdsignal1,bias_ma  f_date:  20180604  pred_date:  20180611  final2= 14.132109864955554
# ppo,ema30,d,ema3_slope,bias_3_6  f_date:  20180604  pred_date:  20180611  final2= 13.226177749770496
# nbias3,ema20,ema30,macdsignal1,rocr  f_date:  20180528  pred_date:  20180611  final2= 12.330886965837664
# ema20,rocr,nbias3,macdsignal1,k  f_date:  20180528  pred_date:  20180611  final2= 12.329110776903535
# ema20,rocr,nbias3,macdsignal1,ema10  f_date:  20180528  pred_date:  20180611  final2= 12.441993123457648
# ema20,rocr,nbias3,macdsignal1,dif  f_date:  20180528  pred_date:  20180611  final2= 12.390630499713618
# ema20,rocr,nbias3,macdsignal1,ema30  f_date:  20180528  pred_date:  20180611  final2= 11.981412851880611
# nbias3,ema20,ema30,macdsignal1,ema5_slope  f_date:  20180528  pred_date:  20180611  final1= 12.81598443257469
# nbias6,ema3_slope,macdsignal1,ema30,d  f_date:  20180528  pred_date:  20180611  final2= 13.70907716752455
# ema20,rocr,nbias3,ema3_slope,bias_ma  f_date:  20180528  pred_date:  20180611  final2= 12.613888676481935
# ema20,rocr,nbias3,ema3_slope,ema10_slope  f_date:  20180528  pred_date:  20180611  final1= 13.016748021619149
# ema20,rocr,ema3_slope,ema5_slope,bias_ma  f_date:  20180528  pred_date:  20180611  final2= 12.546531208527
# ema20,rocr,nbias3,macdsignal1,bias_3_6  f_date:  20180528  pred_date:  20180611  final2= 12.616070876304713
# ema20,rocr,ema3_slope,ema5_slope,macdsignal1  f_date:  20180528  pred_date:  20180611  final2= 12.637678987076894
# ema20,rocr,nbias3,macdsignal1,ema5  f_date:  20180528  pred_date:  20180611  final2= 12.25830523401169
# ema20,rocr,d,ema3_slope,bias_ma  f_date:  20180528  pred_date:  20180611  final2= 13.18859980205411
# ema20,rocr,ema3_slope,nbias6,macdsignal1  f_date:  20180528  pred_date:  20180611  final2= 12.440540733998345
# ema30,ppo,rocr,macdsignal1,macd1  f_date:  20180521  pred_date:  20180611  final2= 12.107090055239855
# ema5,dif,nbias20,rocr,ema30  f_date:  20180521  pred_date:  20180611  final2= 12.452937975070087
# ema3,rocr,nbias20,dif,bias_ma  f_date:  20180521  pred_date:  20180611  final2= 13.128969017806082
# ema5,dif,nbias20,rocr,bias_ma  f_date:  20180521  pred_date:  20180611  final2= 12.847687814055291
# ema5,dif,nbias20,rocr,ema10  f_date:  20180521  pred_date:  20180611  final2= 12.09693201219492
# ema5,dif,nbias20,ema20,cmo  f_date:  20180521  pred_date:  20180611  final2= 12.11795365957563
# ema5,dif,nbias20,rocr,ema20  f_date:  20180521  pred_date:  20180611  final2= 12.911616485808192
# ema3,rocr,nbias20,dif,ema20  f_date:  20180521  pred_date:  20180611  final2= 12.622240625912351
# ema3,rocr,nbias20,dif,bias_3_6  f_date:  20180521  pred_date:  20180611  final2= 12.32088329423193
# ema3,rocr,nbias20,macdhist1,ema30  f_date:  20180521  pred_date:  20180611  final1= 11.511770960360577
# ema5,dif,nbias20,rocr,cmo  f_date:  20180521  pred_date:  20180611  final2= 11.895135696921914
# ema3,rsi,dif,ema20,d  f_date:  20180521  pred_date:  20180611  final2= 12.3805927062157
# ema10,rocr,d,nbias20,macdhist1  f_date:  20180521  pred_date:  20180611  final1= 12.86213954061435
# ema3,rocr,nbias20,dif,ema5  f_date:  20180521  pred_date:  20180611  final2= 12.588919060385436
# ema5,dif,nbias20,ema20,bias_3_6  f_date:  20180521  pred_date:  20180611  final2= 11.71449977076632
# k,ema30,ema5_slope,ema20,dif  f_date:  20180514  pred_date:  20180611  final2= 12.179922737004118
# ema3_slope,ema10,ema30,d,ppo  f_date:  20180514  pred_date:  20180611  final2= 13.462513947387599
# ema3_slope,ema20,dif,bias_3_6,ppo  f_date:  20180514  pred_date:  20180611  final2= 13.828442936934264
# ema3_slope,ema10,ema30,d,dif  f_date:  20180514  pred_date:  20180611  final2= 13.594342376258215
# ema3_slope,ema10,d,ema30,ema20  f_date:  20180514  pred_date:  20180611  final2= 13.082993725848361
# ema3_slope,ema20,dif,bias_3_6,macd1  f_date:  20180514  pred_date:  20180611  final2= 14.112724649024722
# ema3_slope,ema10,d,ema30,ppo  f_date:  20180514  pred_date:  20180611  final2= 13.29889491870055
# ema3_slope,ema10,ema30,d,macd1  f_date:  20180514  pred_date:  20180611  final2= 14.207280165850523
# ema3_slope,ema10,d,ema30,dif  f_date:  20180514  pred_date:  20180611  final2= 13.389023822289852
# ema3_slope,ema10,ppo,ema30,k  f_date:  20180514  pred_date:  20180611  final2= 13.341348712310333
# ema3_slope,ema10,ema30,dif,ppo  f_date:  20180514  pred_date:  20180611  final2= 13.578573433141264
# ema3_slope,ema20,d,ema10,ema30  f_date:  20180514  pred_date:  20180611  final2= 13.260779812661847
# ema3_slope,ema10,ema30,dif,nbias3  f_date:  20180514  pred_date:  20180611  final2= 12.652220630765001
# ema3_slope,ema10,ppo,nbias3,ema20  f_date:  20180514  pred_date:  20180611  final2= 12.71635942101384
# ema3_slope,ema10,ppo,nbias3,k  f_date:  20180514  pred_date:  20180611  final2= 13.671086997798048
# ema20,ema10_slope,nbias3,k,d  f_date:  20180507  pred_date:  20180611  final2= 12.3228925035433
# ema30,ema10_slope,ema3_slope,k,nbias3  f_date:  20180507  pred_date:  20180611  final2= 13.391695706031998
# ema10_slope,ema20,nbias3,ema3_slope,d  f_date:  20180507  pred_date:  20180611  final2= 13.409021820783723
# ema3_slope,ema10_slope,ema30,nbias3,macdhist1  f_date:  20180507  pred_date:  20180611  final2= 14.103902065748459
# ema10_slope,ema20,nbias3,ema3_slope,nbias6  f_date:  20180507  pred_date:  20180611  final2= 12.775502446891855
# ema3_slope,ema10_slope,ema20,nbias3,bias_ma  f_date:  20180507  pred_date:  20180611  final2= 13.372406554471482
# ema20,ema10_slope,ema3_slope,nbias3,bias_3_6  f_date:  20180507  pred_date:  20180611  final2= 12.352251381993927
# ema10_slope,ema20,ema3_slope,bias_3_6,ema30  f_date:  20180507  pred_date:  20180611  final2= 12.380386190332654
# ema10_slope,ema20,nbias3,rocr,k  f_date:  20180507  pred_date:  20180611  final2= 13.141863578342361
# ema10_slope,ema20,ema3_slope,bias_3_6,bias_ma  f_date:  20180507  pred_date:  20180611  final2= 12.54518698311222
# ema3_slope,ema10_slope,ema30,nbias3,ema20  f_date:  20180507  pred_date:  20180611  final2= 13.649478846280395
# ema10_slope,ema20,nbias3,ema3_slope,bias_3_6  f_date:  20180507  pred_date:  20180611  final2= 13.032443933930605
# ema30,ema10_slope,ema3_slope,k,ema5_slope  f_date:  20180507  pred_date:  20180611  final2= 12.80122837848266
# ema20,ema10_slope,nbias3,k,rocr  f_date:  20180507  pred_date:  20180611  final2= 12.729632477687652
# ema3_slope,ema10_slope,ema20,nbias3,ema5_slope  f_date:  20180507  pred_date:  20180611  final2= 12.561402560360781

# %%
# etf_dic['0050']
# score_dic['feature']

# %%
# find top 7 feature combinations
f_str_list = []
f_score_list = []
f_type_list = []
for feature_str in feature_dic.keys():
    f_pd = score_pd.loc[score_pd.feature == feature_str]
    f_scores = f_pd['final_score'].values.tolist()
    if f_scores is None or len(f_scores) == 0:
        continue
    f_score_avg = avg_list(f_scores)
    f_str = f_pd['feature'].values[0]
    f_type_list.append(f_pd['feature_type'].values[0])
    f_str_list.append(f_str)
    f_score_list.append(f_score_avg)

feature_filter_pd_tmp = pd.DataFrame({"feature": f_str_list, "final_score": f_score_list, "f_type" : f_type_list})
feature_filter_pd_tmp.shape
len(f_score_list)
# Out:
# 90

# %%
feature_filter_pd=feature_filter_pd_tmp.loc[feature_filter_pd_tmp.final_score > 13.55] \
                .sort_values(by=['final_score'], ascending=[0])
feature_filter_pd.shape
# Out:
# (29, 3)

# %%
def train_and_eval_final(feature_dic, etf_dic, train_dt, next_pd_dic, date_range, scaler_dic, etf_ids, tetf_pd_eval, doEval):    
    type_list = []
    feature_list = []
    acc_list = []
    rmse_list = []
    escore_list = []
    all_pred_list = []
    etf_pd_dic = {}
    predict_start_date = date_range[0]
    # for features in itertools.combinations(feature_cols, feature_num):
    for feature_str in feature_dic.keys():    
        f_type = feature_dic[feature_str]
        feature_cols = list(feature_str.split(','))
        model = trainModel(train_dt, feature_cols, f_type)
        #recover to re-run
        for eid in etf_ids:
            etf_dt = etf_dic[eid.strip()]
            etf_dt = etf_dt.loc[~etf_dt["etf_date"].isin(date_range)]
            etf_dic.update({eid.strip(): etf_dt})
            etf_pd, next_pd, _ = create_feature(etf_dic[eid.strip()], predict_start_date, scaler_dic)
    #         print(eid.strip(), ': ', etf_pd.shape)
            etf_pd_dic.update({eid.strip() : etf_pd})
            next_pd_dic.update({eid.strip() : next_pd})
        if f_type == '1':
            #evaluate close_dif
            predict_res_pd_1 = doPredict1(date_range, model, etf_dic, next_pd_dic, scaler_dic, feature_cols, etf_ids)
            all_pred_list = all_pred_list + predict_res_pd_1
            if doEval:
                rmse1, acc1, e_score1 = doEvaluate(predict_res_pd_1, tetf_pd_eval, date_range)
                type_list.append("1")
                feature_list.append(feature_str)
                acc_list.append(acc1)
                rmse_list.append(rmse1)
                escore_list.append(e_score1)
                print(feature_str, ' f_date: ', f_date, ' pred_date: ', predict_start_date,' final1=', e_score1)
        else:
            #evaluate etf_close
            predict_res_pd_2 = doPredict2(date_range, model, etf_dic, next_pd_dic, scaler_dic, feature_cols, etf_ids)
            all_pred_list = all_pred_list + predict_res_pd_2
            if doEval:
                rmse2, acc2, e_score2 = doEvaluate(predict_res_pd_2, tetf_pd_eval, date_range)
                type_list.append("2")
                feature_list.append(feature_str)
                acc_list.append(acc2)
                rmse_list.append(rmse2)
                escore_list.append(e_score2)
                print(feature_str, ' f_date: ', f_date, ' pred_date: ', predict_start_date,' final2=', e_score2)

    score_dic = {
        'feature_type' : type_list, 'feature': feature_list, 'accuracy': acc_list, 'rmse': rmse_list,
        'final_score': escore_list, 'pred_date': predict_start_date
    }
    
    return (score_dic, all_pred_list)

# %%
doEval = False
score_pd = None
final_etf_dic = {}

final_feature_dic = {}
for index, row in feature_filter_pd.iterrows():
    f_str = row['feature']
    f_type = row['f_type']
    final_feature_dic.update({f_str: f_type})

for eid in etf_ids:
    end_date = pred_date_range[0]
    etf_dt = etf_dic[eid.strip()]
    final_etf_dt = etf_dt.loc[(etf_dt['etf_id'] == eid) & (etf_dt['etf_date'] < end_date)]
    final_etf_dic.update({eid.strip(): final_etf_dt})
train_dt, next_pd_dic, scaler_dic = create_train_dt(final_etf_dic, pred_date_range, etf_ids)
score_dic,all_pred_list = train_and_eval_final(final_feature_dic, final_etf_dic, train_dt, next_pd_dic, 
                                               pred_date_range, scaler_dic, etf_ids, tetf_pd_eval, doEval)
if score_pd is None:
    score_pd = pd.DataFrame(data=score_dic)[['feature_type', 'feature', 'pred_date', 'accuracy', 'rmse', 'final_score']]
else:
    tmp_pd = pd.DataFrame(data=score_dic)[['feature_type', 'feature', 'pred_date', 'accuracy', 'rmse', 'final_score']]
    score_pd = pd.concat([score_pd, tmp_pd])
# Out:
# train_dt count: (16071, 26)
# next_pd_dic count: 18 * (1, 26)

# %%
# eid = '0050   '
# end_date = pred_date_range[0]
# etf_dt = etf_dic[eid.strip()]
# print(etf_dt.shape)
# final_etf_dt = etf_dt.loc[(etf_dt['etf_id'] == eid) & (etf_dt['etf_date'] < end_date)]
# final_etf_dt

# %%
def judge_ud(ud_list):
    num_1 = 0
    num_0 = 0
    num_2 = 0
    for ud in ud_list:
        if ud == 1.0:
            num_1 += 1
        elif ud == 2.0:
            num_2 += 1
        else:
            num_0 += 1
    if num_2 >= num_1 and num_2 >= num_0:
        return 2.0
    if num_1 >= num_2 and num_1 >= num_0:
        return 1.0
    return 0.0

all_pred_pd = pd.DataFrame(all_pred_list)
predict_res_final = []
for date in pred_date_range:
    for eid in etf_ids:
        pred_pd = all_pred_pd.loc[(all_pred_pd['etf_id'] == eid) & (all_pred_pd['etf_date'] == date)]
        ud_list = pred_pd['pred_ud'].tolist()
        ud = judge_ud(ud_list)
        close_list = pred_pd["prediction"].tolist()
        close = avg_list(close_list)
        predict_res_final.append({
            'etf_id': eid, 'etf_date': date,
            'prediction': close, 'pred_ud': ud
        })

if doEval:
    rmse, acc, e_score = doEvaluate(predict_res_final, tetf_pd_eval, pred_date_range)
    print(predict_start_date, ' final: rmse=', rmse, ', accuracy=', acc, 'etf_score=', e_score)

# 20180611  final: rmse= 0.1892458876114548 , accuracy= 0.6222222222222222 etf_score= 14.4x (feature score thresh > 13.55)
# 20180604  final: rmse= 0.41995557173680387 , accuracy= 0.7111111111111111 etf_score= 14.955692517476345
# 20180528  final: rmse= 0.3927890614192283 , accuracy= 0.5 etf_score= 13.503336673254227
#$$$

# %%
final_res = spark.createDataFrame(pd.DataFrame(predict_res_final)).orderBy("etf_id", "etf_date").collect()
#export to pandas
etf_ids = []
mon_ud = []
mon_price = [] 
tue_ud = []
tue_price = []
wed_ud = []
wed_price = []
thu_ud = []
thu_price = []
fri_ud = []
fri_price = []

def encode_ud(oper_ud):
    if oper_ud == 0.0:
        return 0
    elif oper_ud == 1.0:
        return 1
    else:
        return -1

for row in final_res:
    etf_id = row["etf_id"]
    if etf_id not in etf_ids:
        etf_ids.append(etf_id)
    etf_date = row["etf_date"]
    eidx = pred_date_range.index(row["etf_date"])
    if eidx == 0:
        mon_ud.append(encode_ud(row["pred_ud"]))
        mon_price.append(row["prediction"])
    elif eidx == 1:
        tue_ud.append(encode_ud(row["pred_ud"]))
        tue_price.append(row["prediction"])
    elif eidx == 2:
        wed_ud.append(encode_ud(row["pred_ud"]))
        wed_price.append(row["prediction"])
    elif eidx == 3:
        thu_ud.append(encode_ud(row["pred_ud"]))
        thu_price.append(row["prediction"])
    elif eidx == 4:
        fri_ud.append(encode_ud(row["pred_ud"]))
        fri_price.append(row["prediction"])
        
if len(mon_ud) == 0:
    mon_ud = list(0 for i in range(0,len(etf_ids)))
    mon_price = list(0.0 for i in range(0,len(etf_ids)))
if len(tue_ud) == 0:
    tue_ud = list(0 for i in range(0,len(etf_ids)))
    tue_price = list(0.0 for i in range(0,len(etf_ids)))
if len(wed_ud) == 0:
    wed_ud = list(0 for i in range(0,len(etf_ids)))
    wed_price = list(0.0 for i in range(0,len(etf_ids)))
if len(thu_ud) == 0:
    thu_ud = list(0 for i in range(0,len(etf_ids)))
    thu_price = list(0.0 for i in range(0,len(etf_ids)))
if len(fri_ud) == 0:
    fri_ud = list(0 for i in range(0,len(etf_ids)))
    fri_price = list(0.0 for i in range(0,len(etf_ids)))
    
dic = {"ETFid": etf_ids, 
       "Mon_ud": mon_ud, "Mon_cprice": mon_price,
       "Tue_ud": tue_ud, "Tue_cprice": tue_price,
       "Wed_ud": wed_ud, "Wed_cprice": wed_price,
       "Thu_ud": thu_ud, "Thu_cprice": thu_price,
       "Fri_ud": fri_ud, "Fri_cprice": fri_price
      }
final_df = pd.DataFrame(data=dic)[['ETFid','Mon_ud','Mon_cprice','Tue_ud','Tue_cprice',
                                  'Wed_ud','Wed_cprice','Thu_ud','Thu_cprice',
                                  'Fri_ud','Fri_cprice']]
final_df
# Out:
#       ETFid  Mon_ud  Mon_cprice  Tue_ud  Tue_cprice  Wed_ud  Wed_cprice  \
# 0   0050          1   82.162807       1   82.401798       1   82.495368
# 1   0051          1   34.462594       1   34.560597       1   34.690643
# 2   0052          1   51.795501       1   52.077843       1   52.407006
# 3   0053          1   36.444330       1   36.463727       1   36.490673
# 4   0054         -1   24.539400       1   24.558577       1   24.657678
# 5   0055          1   17.691129       1   17.818669       1   17.876161
# 6   0056          1   26.319569      -1   26.174876      -1   26.099132
# 7   0057          1   50.333889       1   50.468913       1   50.534307
# 8   0058         -1   47.680591       1   47.700835       1   47.814597
# 9   0059          1   42.891126       1   43.005540       1   43.010028
# 10  006201        1   14.510380       1   14.523492       1   14.543026
# 11  006203        1   38.200433       1   38.204397       1   38.286259
# 12  006204        1   55.003584      -1   54.827972       1   54.859755
# 13  006208       -1   47.476404       1   47.490235       1   47.688116
# 14  00690         1   22.270652       1   22.309077       1   22.369413
# 15  00692         1   21.225688       1   21.270850       1   21.329887
# 16  00701         1   21.279395       1   21.305334       1   21.303315
# 17  00713         1   30.886437       1   30.896886       1   30.927137
#
#     Thu_ud  Thu_cprice  Fri_ud  Fri_cprice
# 0        1   82.538515       0         0.0
# 1        1   34.880828       0         0.0
# 2        1   52.856626       0         0.0
# 3        1   36.592246       0         0.0
# 4        1   24.800291       0         0.0
# 5       -1   17.872957       0         0.0
# 6        1   26.036389       0         0.0
# 7        1   50.648864       0         0.0
# 8        1   47.990711       0         0.0
# 9        1   43.047741       0         0.0
# 10       1   14.556159       0         0.0
# 11       1   38.336048       0         0.0
# 12      -1   54.734399       0         0.0
# 13       1   47.976295       0         0.0
# 14       1   22.412389       0         0.0
# 15       1   21.381313       0         0.0
# 16       1   21.344293       0         0.0
# 17       1   30.924430       0         0.0

# %%
final_df.to_csv(Path.replace("file:","") + "/etf_price_pred_talib_eval_mac_5f_" + pred_date_range[0] +".csv",index=False)
